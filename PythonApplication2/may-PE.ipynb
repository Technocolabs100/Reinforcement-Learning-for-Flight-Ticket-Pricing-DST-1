# %%
import pandas as pd
import json
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait 
from selenium.webdriver.support import expected_conditions
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np
from datetime import date, timedelta, datetime
import time
df=pd.read_csv("cities.csv")

# %%
df
# Out:
#    Code IMP_codes
# 0   AGR       DEL
# 1   DIB       BOM
# 2   HYD       BLR
# 3   BHJ       HYD
# 4   HBX       MAA
# ..  ...       ...
# 79  IXS       NaN
# 80  CNN       NaN
# 81  GOI       NaN
# 82  AMD       NaN
# 83  TIR       NaN
#
# [84 rows x 2 columns]

# %%
df["IMP_codes"].iloc[29]
# Out:
# 'TRZ'

# %%
from tqdm import tqdm
price=[]
cities=[]
departure_time=[]
arrival_time=[]
via=[]
airline=[]
cabin=[]
driver = webdriver.Chrome("C:\Program Files (x86)\chromedriver.exe")

for z in range(1,17):
    for m in range(25,27):
        for n in range(30):
            if df["IMP_codes"].iloc[m]!=df["IMP_codes"].iloc[n]:
                print("source=",m, "destination=",n, "Dates=",z)
                print(df["IMP_codes"].iloc[m],df["IMP_codes"].iloc[n])
                k=''
                if(z<10):
                    k='0'
                url="https://www.makemytrip.com/flight/search?itinerary="+df["IMP_codes"].iloc[m]+"-"+df["IMP_codes"].iloc[n]+"-"+k+str(z)+"/05/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&cabinClass=PE&ccde=IN&lang=eng"
                #driver = webdriver.Chrome("C:/chromedriver.exe")
                driver.get(url)
                soup=BeautifulSoup(driver.page_source, 'lxml')

                price_info=soup.find_all('p',attrs={'class': 'blackText fontSize18 blackFont'})
                flights_info=soup.find_all('p',attrs={'class': 'flightDetailsHead'})
                time_info=soup.find_all('p',attrs={'class':"blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"})
                layover_info=soup.find_all('p',attrs={'class': 'flightsLayoverInfo'})
                airline_info=soup.find_all('span',attrs={'class': 'boldFont blackText airlineName'})

#price_info
                for i,j in enumerate(price_info):
                    if i<30:
                       a=str(j)
                       price.append(a[43:len(a)-4])
                      
    #flights_info
                for i,j in enumerate(flights_info):
                    if i<60:
                        k=str(j)
                        if len(k)>45:
                            cities.append(k[29:(len(k)-4)])

    #time_info
                for i,j in enumerate(time_info):
                    if i<60:
                        k=str(j)
                        if (i%2==0):
                            departure_time.append(k[82:87])
                        if (i%2!=0):
                            arrival_time.append(k[82:87])

    #layover_info
                for i,j in enumerate(layover_info):
                    if i<30:
                        k=str(j)
                        via.append(k[30:len(k)-4])

    #airline_info
                for i,j in enumerate(airline_info):
                    if i<30:            
                        k=str(j)
                        airline.append(k[45:len(k)-7])
                print("**"*50)
                print(len(departure_time), len(price),len(cities),len(arrival_time),len(via),len(airline))
# Out:
# source= 25 destination= 0 Dates= 1
# IXC DEL
# ****************************************************************************************************
# 2 2 2 2 2 2
# source= 25 destination= 1 Dates= 1
# IXC BOM
# ****************************************************************************************************
# 2 2 2 2 2 2
# source= 25 destination= 2 Dates= 1
# IXC BLR
# ****************************************************************************************************
# 2 2 2 2 2 2
# source= 25 destination= 3 Dates= 1
# IXC HYD
# ****************************************************************************************************
# 3 3 3 3 3 3
# source= 25 destination= 4 Dates= 1
# IXC MAA
# ****************************************************************************************************
# 3 3 3 3 3 3
# source= 25 destination= 5 Dates= 1
# IXC CCU
# ****************************************************************************************************
# 3 3 3 3 3 3
# source= 25 destination= 6 Dates= 1
# IXC COK
# ****************************************************************************************************
# 3 3 3 3 3 3
# source= 25 destination= 7 Dates= 1
# IXC GOI
# ****************************************************************************************************
# 3 3 3 3 3 3
# source= 25 destination= 8 Dates= 1
# IXC PNQ
# ****************************************************************************************************
# 3 3 3 3 3 3
# source= 25 destination= 9 Dates= 1
# IXC GAU
# ****************************************************************************************************
# 3 3 3 3 3 3
# source= 25 destination= 10 Dates= 1
# IXC LKO
# ****************************************************************************************************
# 3 3 3 3 3 3
# source= 25 destination= 11 Dates= 1
# IXC JAI
# ****************************************************************************************************
# 3 3 3 3 3 3
# source= 25 destination= 12 Dates= 1
# IXC PAT
# ****************************************************************************************************
# 3 3 3 3 3 3
# source= 25 destination= 13 Dates= 1
# IXC TRV
# ****************************************************************************************************
# 3 3 3 3 3 3
# source= 25 destination= 14 Dates= 1
# IXC BBI
# ****************************************************************************************************
# 4 4 4 4 4 4
# source= 25 destination= 15 Dates= 1
# IXC CCJ
# ****************************************************************************************************
# 4 4 4 4 4 4
# source= 25 destination= 16 Dates= 1
# IXC IXB
# ****************************************************************************************************
# 4 4 4 4 4 4
# source= 25 destination= 17 Dates= 1
# IXC NAG
# ****************************************************************************************************
# 4 4 4 4 4 4
# source= 25 destination= 18 Dates= 1
# IXC VNS
# ****************************************************************************************************
# 4 4 4 4 4 4
# source= 25 destination= 19 Dates= 1
# IXC IDR
# ****************************************************************************************************
# 6 6 6 6 6 6
# source= 25 destination= 20 Dates= 1
# IXC CJB
# ****************************************************************************************************
# 6 6 6 6 6 6
# source= 25 destination= 21 Dates= 1
# IXC SXR
# ****************************************************************************************************
# 6 6 6 6 6 6
# source= 25 destination= 22 Dates= 1
# IXC VTZ
# ****************************************************************************************************
# 6 6 6 6 6 6
# source= 25 destination= 23 Dates= 1
# IXC IXR
# ****************************************************************************************************
# 6 6 6 6 6 6
# source= 25 destination= 24 Dates= 1
# IXC ATQ
# ****************************************************************************************************
# 6 6 6 6 6 6
# source= 25 destination= 26 Dates= 1
# IXC RPR
# ****************************************************************************************************
# 7 7 7 7 7 7
# source= 25 destination= 27 Dates= 1
# IXC IXE
# ****************************************************************************************************
# 7 7 7 7 7 7
# source= 25 destination= 28 Dates= 1
# IXC IXZ
# ****************************************************************************************************
# 7 7 7 7 7 7
# source= 25 destination= 29 Dates= 1
# IXC TRZ
# ****************************************************************************************************
# 7 7 7 7 7 7
# source= 26 destination= 0 Dates= 1
# RPR DEL
# ****************************************************************************************************
# 9 9 9 9 9 9
# source= 26 destination= 1 Dates= 1
# RPR BOM
# ****************************************************************************************************
# 10 10 10 10 10 10
# source= 26 destination= 2 Dates= 1
# RPR BLR
# ****************************************************************************************************
# 11 11 11 11 11 11
# source= 26 destination= 3 Dates= 1
# RPR HYD
# ****************************************************************************************************
# 11 11 11 11 11 11
# source= 26 destination= 4 Dates= 1
# RPR MAA
# ****************************************************************************************************
# 12 12 12 12 12 12
# source= 26 destination= 5 Dates= 1
# RPR CCU
# ****************************************************************************************************
# 13 13 13 13 13 13
# source= 26 destination= 6 Dates= 1
# RPR COK
# ****************************************************************************************************
# 15 15 15 15 15 15
# source= 26 destination= 7 Dates= 1
# RPR GOI
# ****************************************************************************************************
# 16 16 16 16 16 16
# source= 26 destination= 8 Dates= 1
# RPR PNQ
# ****************************************************************************************************
# 16 16 16 16 16 16
# source= 26 destination= 9 Dates= 1
# RPR GAU
# ****************************************************************************************************
# 18 18 18 18 18 18
# source= 26 destination= 10 Dates= 1
# RPR LKO
# ****************************************************************************************************
# 19 19 19 19 19 19
# source= 26 destination= 11 Dates= 1
# RPR JAI
# ****************************************************************************************************
# 19 19 19 19 19 19
# source= 26 destination= 12 Dates= 1
# RPR PAT
# ****************************************************************************************************
# 19 19 19 19 19 19
# source= 26 destination= 13 Dates= 1
# RPR TRV
# ****************************************************************************************************
# 19 19 19 19 19 19
# source= 26 destination= 14 Dates= 1
# RPR BBI
# ****************************************************************************************************
# 19 19 19 19 19 19
# source= 26 destination= 15 Dates= 1
# RPR CCJ
# ****************************************************************************************************
# 19 19 19 19 19 19
# source= 26 destination= 16 Dates= 1
# RPR IXB
# ****************************************************************************************************
# 19 19 19 19 19 19
# source= 26 destination= 17 Dates= 1
# RPR NAG
# ****************************************************************************************************
# 19 19 19 19 19 19
# source= 26 destination= 18 Dates= 1
# RPR VNS
# ****************************************************************************************************
# 19 19 19 19 19 19
# source= 26 destination= 19 Dates= 1
# RPR IDR
# ****************************************************************************************************
# 21 21 21 21 21 21
# source= 26 destination= 20 Dates= 1
# RPR CJB
# ****************************************************************************************************
# 21 21 21 21 21 21
# source= 26 destination= 21 Dates= 1
# RPR SXR
# ****************************************************************************************************
# 22 22 22 22 22 22
# source= 26 destination= 22 Dates= 1
# RPR VTZ
# ****************************************************************************************************
# 22 22 22 22 22 22
# source= 26 destination= 23 Dates= 1
# RPR IXR
# ****************************************************************************************************
# 24 24 24 24 24 24
# source= 26 destination= 24 Dates= 1
# RPR ATQ
# ****************************************************************************************************
# 24 24 24 24 24 24
# source= 26 destination= 25 Dates= 1
# RPR IXC
# ****************************************************************************************************
# 25 25 25 25 25 25
# source= 26 destination= 27 Dates= 1
# RPR IXE
# ****************************************************************************************************
# 25 25 25 25 25 25
# source= 26 destination= 28 Dates= 1
# RPR IXZ
# ****************************************************************************************************
# 27 27 27 27 27 27
# source= 26 destination= 29 Dates= 1
# RPR TRZ
# ****************************************************************************************************
# 27 27 27 27 27 27
# source= 25 destination= 0 Dates= 2
# IXC DEL
# ****************************************************************************************************
# 29 29 29 29 29 29
# source= 25 destination= 1 Dates= 2
# IXC BOM
# ****************************************************************************************************
# 32 32 32 32 32 32
# source= 25 destination= 2 Dates= 2
# IXC BLR
# ****************************************************************************************************
# 32 32 32 32 32 32
# source= 25 destination= 3 Dates= 2
# IXC HYD
# ****************************************************************************************************
# 33 33 33 33 33 33
# source= 25 destination= 4 Dates= 2
# IXC MAA
# ****************************************************************************************************
# 34 34 34 34 34 34
# source= 25 destination= 5 Dates= 2
# IXC CCU
# ****************************************************************************************************
# 34 34 34 34 34 34
# source= 25 destination= 6 Dates= 2
# IXC COK
# ****************************************************************************************************
# 35 35 35 35 35 35
# source= 25 destination= 7 Dates= 2
# IXC GOI
# ****************************************************************************************************
# 36 36 36 36 36 36
# source= 25 destination= 8 Dates= 2
# IXC PNQ
# ****************************************************************************************************
# 36 36 36 36 36 36
# source= 25 destination= 9 Dates= 2
# IXC GAU
# ****************************************************************************************************
# 37 37 37 37 37 37
# source= 25 destination= 10 Dates= 2
# IXC LKO
# ****************************************************************************************************
# 37 37 37 37 37 37
# source= 25 destination= 11 Dates= 2
# IXC JAI
# ****************************************************************************************************
# 37 37 37 37 37 37
# source= 25 destination= 12 Dates= 2
# IXC PAT
# ****************************************************************************************************
# 37 37 37 37 37 37
# source= 25 destination= 13 Dates= 2
# IXC TRV
# ****************************************************************************************************
# 37 37 37 37 37 37
# source= 25 destination= 14 Dates= 2
# IXC BBI
# ****************************************************************************************************
# 39 39 39 39 39 39
# source= 25 destination= 15 Dates= 2
# IXC CCJ
# ****************************************************************************************************
# 39 39 39 39 39 39
# source= 25 destination= 16 Dates= 2
# IXC IXB
# ****************************************************************************************************
# 42 42 42 42 42 42
# source= 25 destination= 17 Dates= 2
# IXC NAG
# ****************************************************************************************************
# 42 42 42 42 42 42
# source= 25 destination= 18 Dates= 2
# IXC VNS
# ****************************************************************************************************
# 46 46 46 46 46 46
# source= 25 destination= 19 Dates= 2
# IXC IDR
# ****************************************************************************************************
# 50 50 50 50 50 50
# source= 25 destination= 20 Dates= 2
# IXC CJB
# ****************************************************************************************************
# 50 50 50 50 50 50
# source= 25 destination= 21 Dates= 2
# IXC SXR
# ****************************************************************************************************
# 52 52 52 52 52 52
# source= 25 destination= 22 Dates= 2
# IXC VTZ
# ****************************************************************************************************
# 52 52 52 52 52 52
# source= 25 destination= 23 Dates= 2
# IXC IXR
# ****************************************************************************************************
# 52 52 52 52 52 52
# source= 25 destination= 24 Dates= 2
# IXC ATQ
# ****************************************************************************************************
# 52 52 52 52 52 52
# source= 25 destination= 26 Dates= 2
# IXC RPR
# ****************************************************************************************************
# 54 54 54 54 54 54
# source= 25 destination= 27 Dates= 2
# IXC IXE
# ****************************************************************************************************
# 54 54 54 54 54 54
# source= 25 destination= 28 Dates= 2
# IXC IXZ
# ****************************************************************************************************
# 54 54 54 54 54 54
# source= 25 destination= 29 Dates= 2
# IXC TRZ
# ****************************************************************************************************
# 54 54 54 54 54 54
# source= 26 destination= 0 Dates= 2
# RPR DEL
# ****************************************************************************************************
# 54 54 54 54 54 54
# source= 26 destination= 1 Dates= 2
# RPR BOM
# ****************************************************************************************************
# 55 55 55 55 55 55
# source= 26 destination= 2 Dates= 2
# RPR BLR
# ****************************************************************************************************
# 56 56 56 56 56 56
# source= 26 destination= 3 Dates= 2
# RPR HYD
# ****************************************************************************************************
# 57 57 57 57 57 57
# source= 26 destination= 4 Dates= 2
# RPR MAA
# ****************************************************************************************************
# 58 58 58 58 58 58
# source= 26 destination= 5 Dates= 2
# RPR CCU
# ****************************************************************************************************
# 59 59 59 59 59 59
# source= 26 destination= 6 Dates= 2
# RPR COK
# ****************************************************************************************************
# 59 59 59 59 59 59
# source= 26 destination= 7 Dates= 2
# RPR GOI
# ****************************************************************************************************
# 60 60 60 60 60 60
# source= 26 destination= 8 Dates= 2
# RPR PNQ
# ****************************************************************************************************
# 60 60 60 60 60 60
# source= 26 destination= 9 Dates= 2
# RPR GAU
# ****************************************************************************************************
# 62 62 62 62 62 62
# source= 26 destination= 10 Dates= 2
# RPR LKO
# ****************************************************************************************************
# 64 64 64 64 64 64
# source= 26 destination= 11 Dates= 2
# RPR JAI
# ****************************************************************************************************
# 64 64 64 64 64 64
# source= 26 destination= 12 Dates= 2
# RPR PAT
# ****************************************************************************************************
# 64 64 64 64 64 64
# source= 26 destination= 13 Dates= 2
# RPR TRV
# ****************************************************************************************************
# 64 64 64 64 64 64
# source= 26 destination= 14 Dates= 2
# RPR BBI
# ****************************************************************************************************
# 66 66 66 66 66 66
# source= 26 destination= 15 Dates= 2
# RPR CCJ
# ****************************************************************************************************
# 66 66 66 66 66 66
# source= 26 destination= 16 Dates= 2
# RPR IXB
# ****************************************************************************************************
# 68 68 68 68 68 68
# source= 26 destination= 17 Dates= 2
# RPR NAG
# ****************************************************************************************************
# 68 68 68 68 68 68
# source= 26 destination= 18 Dates= 2
# RPR VNS
# ****************************************************************************************************
# 73 73 73 73 73 73
# source= 26 destination= 19 Dates= 2
# RPR IDR
# ****************************************************************************************************
# 75 75 75 75 75 75
# source= 26 destination= 20 Dates= 2
# RPR CJB
# ****************************************************************************************************
# 75 75 75 75 75 75
# source= 26 destination= 21 Dates= 2
# RPR SXR
# ****************************************************************************************************
# 76 76 76 76 76 76
# source= 26 destination= 22 Dates= 2
# RPR VTZ
# ****************************************************************************************************
# 76 76 76 76 76 76
# source= 26 destination= 23 Dates= 2
# RPR IXR
# ****************************************************************************************************
# 76 76 76 76 76 76
# source= 26 destination= 24 Dates= 2
# RPR ATQ
# ****************************************************************************************************
# 76 76 76 76 76 76
# source= 26 destination= 25 Dates= 2
# RPR IXC
# ****************************************************************************************************
# 76 76 76 76 76 76
# source= 26 destination= 27 Dates= 2
# RPR IXE
# ****************************************************************************************************
# 76 76 76 76 76 76
# source= 26 destination= 28 Dates= 2
# RPR IXZ
# ****************************************************************************************************
# 78 78 78 78 78 78
# source= 26 destination= 29 Dates= 2
# RPR TRZ
# ****************************************************************************************************
# 78 78 78 78 78 78
# source= 25 destination= 0 Dates= 3
# IXC DEL
# ****************************************************************************************************
# 80 80 80 80 80 80
# source= 25 destination= 1 Dates= 3
# IXC BOM
# ****************************************************************************************************
# 80 80 80 80 80 80
# source= 25 destination= 2 Dates= 3
# IXC BLR
# ****************************************************************************************************
# 80 80 80 80 80 80
# source= 25 destination= 3 Dates= 3
# IXC HYD
# ****************************************************************************************************
# 80 80 80 80 80 80
# source= 25 destination= 4 Dates= 3
# IXC MAA
# ****************************************************************************************************
# 80 80 80 80 80 80
# source= 25 destination= 5 Dates= 3
# IXC CCU
# ****************************************************************************************************
# 82 82 82 82 82 82
# source= 25 destination= 6 Dates= 3
# IXC COK
# ****************************************************************************************************
# 82 82 82 82 82 82
# source= 25 destination= 7 Dates= 3
# IXC GOI
# ****************************************************************************************************
# 83 83 83 83 83 83
# source= 25 destination= 8 Dates= 3
# IXC PNQ
# ****************************************************************************************************
# 83 83 83 83 83 83
# source= 25 destination= 9 Dates= 3
# IXC GAU
# ****************************************************************************************************
# 83 83 83 83 83 83
# source= 25 destination= 10 Dates= 3
# IXC LKO
# ****************************************************************************************************
# 83 83 83 83 83 83
# source= 25 destination= 11 Dates= 3
# IXC JAI
# ****************************************************************************************************
# 83 83 83 83 83 83
# source= 25 destination= 12 Dates= 3
# IXC PAT
# ****************************************************************************************************
# 83 83 83 83 83 83
# source= 25 destination= 13 Dates= 3
# IXC TRV
# ****************************************************************************************************
# 83 83 83 83 83 83
# source= 25 destination= 14 Dates= 3
# IXC BBI
# ****************************************************************************************************
# 84 84 84 84 84 84
# source= 25 destination= 15 Dates= 3
# IXC CCJ
# ****************************************************************************************************
# 84 84 84 84 84 84
# source= 25 destination= 16 Dates= 3
# IXC IXB
# ****************************************************************************************************
# 84 84 84 84 84 84
# source= 25 destination= 17 Dates= 3
# IXC NAG
# ****************************************************************************************************
# 84 84 84 84 84 84
# source= 25 destination= 18 Dates= 3
# IXC VNS
# ****************************************************************************************************
# 84 84 84 84 84 84
# source= 25 destination= 19 Dates= 3
# IXC IDR
# ****************************************************************************************************
# 85 85 85 85 85 85
# source= 25 destination= 20 Dates= 3
# IXC CJB
# ****************************************************************************************************
# 85 85 85 85 85 85
# source= 25 destination= 21 Dates= 3
# IXC SXR
# ****************************************************************************************************
# 85 85 85 85 85 85
# source= 25 destination= 22 Dates= 3
# IXC VTZ
# ****************************************************************************************************
# 85 85 85 85 85 85
# source= 25 destination= 23 Dates= 3
# IXC IXR
# ****************************************************************************************************
# 85 85 85 85 85 85
# source= 25 destination= 24 Dates= 3
# IXC ATQ
# ****************************************************************************************************
# 85 85 85 85 85 85
# source= 25 destination= 26 Dates= 3
# IXC RPR
# ****************************************************************************************************
# 87 87 87 87 87 87
# source= 25 destination= 27 Dates= 3
# IXC IXE
# ****************************************************************************************************
# 87 87 87 87 87 87
# source= 25 destination= 28 Dates= 3
# IXC IXZ
# ****************************************************************************************************
# 87 87 87 87 87 87
# source= 25 destination= 29 Dates= 3
# IXC TRZ
# ****************************************************************************************************
# 87 87 87 87 87 87
# source= 26 destination= 0 Dates= 3
# RPR DEL
# ****************************************************************************************************
# 89 89 89 89 89 89
# source= 26 destination= 1 Dates= 3
# RPR BOM
# ****************************************************************************************************
# 89 89 89 89 89 89
# source= 26 destination= 2 Dates= 3
# RPR BLR
# ****************************************************************************************************
# 89 89 89 89 89 89
# source= 26 destination= 3 Dates= 3
# RPR HYD
# ****************************************************************************************************
# 90 90 90 90 90 90
# source= 26 destination= 4 Dates= 3
# RPR MAA
# ****************************************************************************************************
# 91 91 91 91 91 91
# source= 26 destination= 5 Dates= 3
# RPR CCU
# ****************************************************************************************************
# 91 91 91 91 91 91
# source= 26 destination= 6 Dates= 3
# RPR COK
# ****************************************************************************************************
# 93 93 93 93 93 93
# source= 26 destination= 7 Dates= 3
# RPR GOI
# ****************************************************************************************************
# 93 93 93 93 93 93
# source= 26 destination= 8 Dates= 3
# RPR PNQ
# ****************************************************************************************************
# 93 93 93 93 93 93
# source= 26 destination= 9 Dates= 3
# RPR GAU
# ****************************************************************************************************
# 93 93 93 93 93 93
# source= 26 destination= 10 Dates= 3
# RPR LKO
# ****************************************************************************************************
# 93 93 93 93 93 93
# source= 26 destination= 11 Dates= 3
# RPR JAI
# ****************************************************************************************************
# 93 93 93 93 93 93
# source= 26 destination= 12 Dates= 3
# RPR PAT
# ****************************************************************************************************
# 93 93 93 93 93 93
# source= 26 destination= 13 Dates= 3
# RPR TRV
# ****************************************************************************************************
# 94 94 94 94 94 94
# source= 26 destination= 14 Dates= 3
# RPR BBI
# ****************************************************************************************************
# 95 95 95 95 95 95
# source= 26 destination= 15 Dates= 3
# RPR CCJ
# ****************************************************************************************************
# 95 95 95 95 95 95
# source= 26 destination= 16 Dates= 3
# RPR IXB
# ****************************************************************************************************
# 95 95 95 95 95 95
# source= 26 destination= 17 Dates= 3
# RPR NAG
# ****************************************************************************************************
# 95 95 95 95 95 95
# source= 26 destination= 18 Dates= 3
# RPR VNS
# ****************************************************************************************************
# 95 95 95 95 95 95
# source= 26 destination= 19 Dates= 3
# RPR IDR
# ****************************************************************************************************
# 95 95 95 95 95 95
# source= 26 destination= 20 Dates= 3
# RPR CJB
# ****************************************************************************************************
# 95 95 95 95 95 95
# source= 26 destination= 21 Dates= 3
# RPR SXR
# ****************************************************************************************************
# 96 96 96 96 96 96
# source= 26 destination= 22 Dates= 3
# RPR VTZ
# ****************************************************************************************************
# 96 96 96 96 96 96
# source= 26 destination= 23 Dates= 3
# RPR IXR
# ****************************************************************************************************
# 98 98 98 98 98 98
# source= 26 destination= 24 Dates= 3
# RPR ATQ
# ****************************************************************************************************
# 98 98 98 98 98 98
# source= 26 destination= 25 Dates= 3
# RPR IXC
# ****************************************************************************************************
# 98 98 98 98 98 98
# source= 26 destination= 27 Dates= 3
# RPR IXE
# ****************************************************************************************************
# 98 98 98 98 98 98
# source= 26 destination= 28 Dates= 3
# RPR IXZ
# ****************************************************************************************************
# 100 100 100 100 100 100
# source= 26 destination= 29 Dates= 3
# RPR TRZ
# ****************************************************************************************************
# 100 100 100 100 100 100
# source= 25 destination= 0 Dates= 4
# IXC DEL
# ****************************************************************************************************
# 102 102 102 102 102 102
# source= 25 destination= 1 Dates= 4
# IXC BOM
# ****************************************************************************************************
# 102 102 102 102 102 102
# source= 25 destination= 2 Dates= 4
# IXC BLR
# ****************************************************************************************************
# 102 102 102 102 102 102
# source= 25 destination= 3 Dates= 4
# IXC HYD
# ****************************************************************************************************
# 103 103 103 103 103 103
# source= 25 destination= 4 Dates= 4
# IXC MAA
# ****************************************************************************************************
# 104 104 104 104 104 104
# source= 25 destination= 5 Dates= 4
# IXC CCU
# ****************************************************************************************************
# 106 106 106 106 106 106
# source= 25 destination= 6 Dates= 4
# IXC COK
# ****************************************************************************************************
# 107 107 107 107 107 107
# source= 25 destination= 7 Dates= 4
# IXC GOI
# ****************************************************************************************************
# 108 108 108 108 108 108
# source= 25 destination= 8 Dates= 4
# IXC PNQ
# ****************************************************************************************************
# 108 108 108 108 108 108
# source= 25 destination= 9 Dates= 4
# IXC GAU
# ****************************************************************************************************
# 108 108 108 108 108 108
# source= 25 destination= 10 Dates= 4
# IXC LKO
# ****************************************************************************************************
# 108 108 108 108 108 108
# source= 25 destination= 11 Dates= 4
# IXC JAI
# ****************************************************************************************************
# 108 108 108 108 108 108
# source= 25 destination= 12 Dates= 4
# IXC PAT
# ****************************************************************************************************
# 108 108 108 108 108 108
# source= 25 destination= 13 Dates= 4
# IXC TRV
# ****************************************************************************************************
# 108 108 108 108 108 108
# source= 25 destination= 14 Dates= 4
# IXC BBI
# ****************************************************************************************************
# 110 110 110 110 110 110
# source= 25 destination= 15 Dates= 4
# IXC CCJ
# ****************************************************************************************************
# 110 110 110 110 110 110
# source= 25 destination= 16 Dates= 4
# IXC IXB
# ****************************************************************************************************
# 111 111 111 111 111 111
# source= 25 destination= 17 Dates= 4
# IXC NAG
# ****************************************************************************************************
# 111 111 111 111 111 111
# source= 25 destination= 18 Dates= 4
# IXC VNS
# ****************************************************************************************************
# 111 111 111 111 111 111
# source= 25 destination= 19 Dates= 4
# IXC IDR
# ****************************************************************************************************
# 111 111 111 111 111 111
# source= 25 destination= 20 Dates= 4
# IXC CJB
# ****************************************************************************************************
# 111 111 111 111 111 111
# source= 25 destination= 21 Dates= 4
# IXC SXR
# ****************************************************************************************************
# 113 113 113 113 113 113
# source= 25 destination= 22 Dates= 4
# IXC VTZ
# ****************************************************************************************************
# 113 113 113 113 113 113
# source= 25 destination= 23 Dates= 4
# IXC IXR
# ****************************************************************************************************
# 113 113 113 113 113 113
# source= 25 destination= 24 Dates= 4
# IXC ATQ
# ****************************************************************************************************
# 113 113 113 113 113 113
# source= 25 destination= 26 Dates= 4
# IXC RPR
# ****************************************************************************************************
# 113 113 113 113 113 113
# source= 25 destination= 27 Dates= 4
# IXC IXE
# ****************************************************************************************************
# 113 113 113 113 113 113
# source= 25 destination= 28 Dates= 4
# IXC IXZ
# ****************************************************************************************************
# 113 113 113 113 113 113
# source= 25 destination= 29 Dates= 4
# IXC TRZ
# ****************************************************************************************************
# 113 113 113 113 113 113
# source= 26 destination= 0 Dates= 4
# RPR DEL
# ****************************************************************************************************
# 113 113 113 113 113 113
# source= 26 destination= 1 Dates= 4
# RPR BOM
# ****************************************************************************************************
# 113 113 113 113 113 113
# source= 26 destination= 2 Dates= 4
# RPR BLR
# ****************************************************************************************************
# 114 114 114 114 114 114
# source= 26 destination= 3 Dates= 4
# RPR HYD
# ****************************************************************************************************
# 115 115 115 115 115 115
# source= 26 destination= 4 Dates= 4
# RPR MAA
# ****************************************************************************************************
# 115 115 115 115 115 115
# source= 26 destination= 5 Dates= 4
# RPR CCU
# ****************************************************************************************************
# 115 115 115 115 115 115
# source= 26 destination= 6 Dates= 4
# RPR COK
# ****************************************************************************************************
# 117 117 117 117 117 117
# source= 26 destination= 7 Dates= 4
# RPR GOI
# ****************************************************************************************************
# 117 117 117 117 117 117
# source= 26 destination= 8 Dates= 4
# RPR PNQ
# ****************************************************************************************************
# 117 117 117 117 117 117
# source= 26 destination= 9 Dates= 4
# RPR GAU
# ****************************************************************************************************
# 119 119 119 119 119 119
# source= 26 destination= 10 Dates= 4
# RPR LKO
# ****************************************************************************************************
# 120 120 120 120 120 120
# source= 26 destination= 11 Dates= 4
# RPR JAI
# ****************************************************************************************************
# 120 120 120 120 120 120
# source= 26 destination= 12 Dates= 4
# RPR PAT
# ****************************************************************************************************
# 120 120 120 120 120 120
# source= 26 destination= 13 Dates= 4
# RPR TRV
# ****************************************************************************************************
# 121 121 121 121 121 121
# source= 26 destination= 14 Dates= 4
# RPR BBI
# ****************************************************************************************************
# 123 123 123 123 123 123
# source= 26 destination= 15 Dates= 4
# RPR CCJ
# ****************************************************************************************************
# 123 123 123 123 123 123
# source= 26 destination= 16 Dates= 4
# RPR IXB
# ****************************************************************************************************
# 125 125 125 125 125 125
# source= 26 destination= 17 Dates= 4
# RPR NAG
# ****************************************************************************************************
# 125 125 125 125 125 125
# source= 26 destination= 18 Dates= 4
# RPR VNS
# ****************************************************************************************************
# 126 126 126 126 126 126
# source= 26 destination= 19 Dates= 4
# RPR IDR
# ****************************************************************************************************
# 126 126 126 126 126 126
# source= 26 destination= 20 Dates= 4
# RPR CJB
# ****************************************************************************************************
# 126 126 126 126 126 126
# source= 26 destination= 21 Dates= 4
# RPR SXR
# ****************************************************************************************************
# 126 126 126 126 126 126
# source= 26 destination= 22 Dates= 4
# RPR VTZ
# ****************************************************************************************************
# 126 126 126 126 126 126
# source= 26 destination= 23 Dates= 4
# RPR IXR
# ****************************************************************************************************
# 126 126 126 126 126 126
# source= 26 destination= 24 Dates= 4
# RPR ATQ
# ****************************************************************************************************
# 126 126 126 126 126 126
# source= 26 destination= 25 Dates= 4
# RPR IXC
# ****************************************************************************************************
# 126 126 126 126 126 126
# source= 26 destination= 27 Dates= 4
# RPR IXE
# ****************************************************************************************************
# 126 126 126 126 126 126
# source= 26 destination= 28 Dates= 4
# RPR IXZ
# ****************************************************************************************************
# 126 126 126 126 126 126
# source= 26 destination= 29 Dates= 4
# RPR TRZ
# ****************************************************************************************************
# 126 126 126 126 126 126
# source= 25 destination= 0 Dates= 5
# IXC DEL
# ****************************************************************************************************
# 128 128 128 128 128 128
# source= 25 destination= 1 Dates= 5
# IXC BOM
# ****************************************************************************************************
# 128 128 128 128 128 128
# source= 25 destination= 2 Dates= 5
# IXC BLR
# ****************************************************************************************************
# 130 130 130 130 130 130
# source= 25 destination= 3 Dates= 5
# IXC HYD
# ****************************************************************************************************
# 131 131 131 131 131 131
# source= 25 destination= 4 Dates= 5
# IXC MAA
# ****************************************************************************************************
# 132 132 132 132 132 132
# source= 25 destination= 5 Dates= 5
# IXC CCU
# ****************************************************************************************************
# 132 132 132 132 132 132
# source= 25 destination= 6 Dates= 5
# IXC COK
# ****************************************************************************************************
# 133 133 133 133 133 133
# source= 25 destination= 7 Dates= 5
# IXC GOI
# ****************************************************************************************************
# 133 133 133 133 133 133
# source= 25 destination= 8 Dates= 5
# IXC PNQ
# ****************************************************************************************************
# 133 133 133 133 133 133
# source= 25 destination= 9 Dates= 5
# IXC GAU
# ****************************************************************************************************
# 133 133 133 133 133 133
# source= 25 destination= 10 Dates= 5
# IXC LKO
# ****************************************************************************************************
# 133 133 133 133 133 133
# source= 25 destination= 11 Dates= 5
# IXC JAI
# ****************************************************************************************************
# 133 133 133 133 133 133
# source= 25 destination= 12 Dates= 5
# IXC PAT
# ****************************************************************************************************
# 133 133 133 133 133 133
# source= 25 destination= 13 Dates= 5
# IXC TRV
# ****************************************************************************************************
# 133 133 133 133 133 133
# source= 25 destination= 14 Dates= 5
# IXC BBI
# ****************************************************************************************************
# 134 134 134 134 134 134
# source= 25 destination= 15 Dates= 5
# IXC CCJ
# ****************************************************************************************************
# 134 134 134 134 134 134
# source= 25 destination= 16 Dates= 5
# IXC IXB
# ****************************************************************************************************
# 137 137 137 137 137 137
# source= 25 destination= 17 Dates= 5
# IXC NAG
# ****************************************************************************************************
# 137 137 137 137 137 137
# source= 25 destination= 18 Dates= 5
# IXC VNS
# ****************************************************************************************************
# 137 137 137 137 137 137
# source= 25 destination= 19 Dates= 5
# IXC IDR
# ****************************************************************************************************
# 138 138 138 138 138 138
# source= 25 destination= 20 Dates= 5
# IXC CJB
# ****************************************************************************************************
# 138 138 138 138 138 138
# source= 25 destination= 21 Dates= 5
# IXC SXR
# ****************************************************************************************************
# 139 139 139 139 139 139
# source= 25 destination= 22 Dates= 5
# IXC VTZ
# ****************************************************************************************************
# 139 139 139 139 139 139
# source= 25 destination= 23 Dates= 5
# IXC IXR
# ****************************************************************************************************
# 139 139 139 139 139 139
# source= 25 destination= 24 Dates= 5
# IXC ATQ
# ****************************************************************************************************
# 139 139 139 139 139 139
# source= 25 destination= 26 Dates= 5
# IXC RPR
# ****************************************************************************************************
# 139 139 139 139 139 139
# source= 25 destination= 27 Dates= 5
# IXC IXE
# ****************************************************************************************************
# 139 139 139 139 139 139
# source= 25 destination= 28 Dates= 5
# IXC IXZ
# ****************************************************************************************************
# 139 139 139 139 139 139
# source= 25 destination= 29 Dates= 5
# IXC TRZ
# ****************************************************************************************************
# 139 139 139 139 139 139
# source= 26 destination= 0 Dates= 5
# RPR DEL
# ****************************************************************************************************
# 141 141 141 141 141 141
# source= 26 destination= 1 Dates= 5
# RPR BOM
# ****************************************************************************************************
# 142 142 142 142 142 142
# source= 26 destination= 2 Dates= 5
# RPR BLR
# ****************************************************************************************************
# 142 142 142 142 142 142
# source= 26 destination= 3 Dates= 5
# RPR HYD
# ****************************************************************************************************
# 142 142 142 142 142 142
# source= 26 destination= 4 Dates= 5
# RPR MAA
# ****************************************************************************************************
# 142 142 142 142 142 142
# source= 26 destination= 5 Dates= 5
# RPR CCU
# ****************************************************************************************************
# 143 143 143 143 143 143
# source= 26 destination= 6 Dates= 5
# RPR COK
# ****************************************************************************************************
# 145 145 145 145 145 145
# source= 26 destination= 7 Dates= 5
# RPR GOI
# ****************************************************************************************************
# 146 146 146 146 146 146
# source= 26 destination= 8 Dates= 5
# RPR PNQ
# ****************************************************************************************************
# 146 146 146 146 146 146
# source= 26 destination= 9 Dates= 5
# RPR GAU
# ****************************************************************************************************
# 148 148 148 148 148 148
# source= 26 destination= 10 Dates= 5
# RPR LKO
# ****************************************************************************************************
# 150 150 150 150 150 150
# source= 26 destination= 11 Dates= 5
# RPR JAI
# ****************************************************************************************************
# 150 150 150 150 150 150
# source= 26 destination= 12 Dates= 5
# RPR PAT
# ****************************************************************************************************
# 150 150 150 150 150 150
# source= 26 destination= 13 Dates= 5
# RPR TRV
# ****************************************************************************************************
# 151 151 151 151 151 151
# source= 26 destination= 14 Dates= 5
# RPR BBI
# ****************************************************************************************************
# 153 153 153 153 153 153
# source= 26 destination= 15 Dates= 5
# RPR CCJ
# ****************************************************************************************************
# 153 153 153 153 153 153
# source= 26 destination= 16 Dates= 5
# RPR IXB
# ****************************************************************************************************
# 155 155 155 155 155 155
# source= 26 destination= 17 Dates= 5
# RPR NAG
# ****************************************************************************************************
# 155 155 155 155 155 155
# source= 26 destination= 18 Dates= 5
# RPR VNS
# ****************************************************************************************************
# 160 160 160 160 160 160
# source= 26 destination= 19 Dates= 5
# RPR IDR
# ****************************************************************************************************
# 162 162 162 162 162 162
# source= 26 destination= 20 Dates= 5
# RPR CJB
# ****************************************************************************************************
# 162 162 162 162 162 162
# source= 26 destination= 21 Dates= 5
# RPR SXR
# ****************************************************************************************************
# 163 163 163 163 163 163
# source= 26 destination= 22 Dates= 5
# RPR VTZ
# ****************************************************************************************************
# 163 163 163 163 163 163
# source= 26 destination= 23 Dates= 5
# RPR IXR
# ****************************************************************************************************
# 165 165 165 165 165 165
# source= 26 destination= 24 Dates= 5
# RPR ATQ
# ****************************************************************************************************
# 167 167 167 167 167 167
# source= 26 destination= 25 Dates= 5
# RPR IXC
# ****************************************************************************************************
# 168 168 168 168 168 168
# source= 26 destination= 27 Dates= 5
# RPR IXE
# ****************************************************************************************************
# 168 168 168 168 168 168
# source= 26 destination= 28 Dates= 5
# RPR IXZ
# ****************************************************************************************************
# 170 170 170 170 170 170
# source= 26 destination= 29 Dates= 5
# RPR TRZ
# ****************************************************************************************************
# 170 170 170 170 170 170
# source= 25 destination= 0 Dates= 6
# IXC DEL
# ****************************************************************************************************
# 172 172 172 172 172 172
# source= 25 destination= 1 Dates= 6
# IXC BOM
# ...
# 464 464 464 464 464 464
# source= 25 destination= 22 Dates= 15
# IXC VTZ
# ****************************************************************************************************
# 464 464 464 464 464 464
# source= 25 destination= 23 Dates= 15
# IXC IXR
# ****************************************************************************************************
# 464 464 464 464 464 464
# source= 25 destination= 24 Dates= 15
# IXC ATQ
# ****************************************************************************************************
# 464 464 464 464 464 464
# source= 25 destination= 26 Dates= 15
# IXC RPR
# ****************************************************************************************************
# 464 464 464 464 464 464
# source= 25 destination= 27 Dates= 15
# IXC IXE
# ****************************************************************************************************
# 464 464 464 464 464 464
# source= 25 destination= 28 Dates= 15
# IXC IXZ
# ****************************************************************************************************
# 464 464 464 464 464 464
# source= 25 destination= 29 Dates= 15
# IXC TRZ
# ****************************************************************************************************
# 464 464 464 464 464 464
# source= 26 destination= 0 Dates= 15
# RPR DEL
# ****************************************************************************************************
# 466 466 466 466 466 466
# source= 26 destination= 1 Dates= 15
# RPR BOM
# ****************************************************************************************************
# 467 467 467 467 467 467
# source= 26 destination= 2 Dates= 15
# RPR BLR
# ****************************************************************************************************
# 467 467 467 467 467 467
# source= 26 destination= 3 Dates= 15
# RPR HYD
# ****************************************************************************************************
# 468 468 468 468 468 468
# source= 26 destination= 4 Dates= 15
# RPR MAA
# ****************************************************************************************************
# 468 468 468 468 468 468
# source= 26 destination= 5 Dates= 15
# RPR CCU
# ****************************************************************************************************
# 468 468 468 468 468 468
# source= 26 destination= 6 Dates= 15
# RPR COK
# ****************************************************************************************************
# 469 469 469 469 469 469
# source= 26 destination= 7 Dates= 15
# RPR GOI
# ****************************************************************************************************
# 470 470 470 470 470 470
# source= 26 destination= 8 Dates= 15
# RPR PNQ
# ****************************************************************************************************
# 472 472 472 472 472 472
# source= 26 destination= 9 Dates= 15
# RPR GAU
# ****************************************************************************************************
# 474 474 474 474 474 474
# source= 26 destination= 10 Dates= 15
# RPR LKO
# ****************************************************************************************************
# 474 474 474 474 474 474
# source= 26 destination= 11 Dates= 15
# RPR JAI
# ****************************************************************************************************
# 474 474 474 474 474 474
# source= 26 destination= 12 Dates= 15
# RPR PAT
# ****************************************************************************************************
# 474 474 474 474 474 474
# source= 26 destination= 13 Dates= 15
# RPR TRV
# ****************************************************************************************************
# 475 475 475 475 475 475
# source= 26 destination= 14 Dates= 15
# RPR BBI
# ****************************************************************************************************
# 476 476 476 476 476 476
# source= 26 destination= 15 Dates= 15
# RPR CCJ
# ****************************************************************************************************
# 476 476 476 476 476 476
# source= 26 destination= 16 Dates= 15
# RPR IXB
# ****************************************************************************************************
# 478 478 478 478 478 478
# source= 26 destination= 17 Dates= 15
# RPR NAG
# ****************************************************************************************************
# 478 478 478 478 478 478
# source= 26 destination= 18 Dates= 15
# RPR VNS
# ****************************************************************************************************
# 481 481 481 481 481 481
# source= 26 destination= 19 Dates= 15
# RPR IDR
# ****************************************************************************************************
# 483 483 483 483 483 483
# source= 26 destination= 20 Dates= 15
# RPR CJB
# ****************************************************************************************************
# 483 483 483 483 483 483
# source= 26 destination= 21 Dates= 15
# RPR SXR
# ****************************************************************************************************
# 484 484 484 484 484 484
# source= 26 destination= 22 Dates= 15
# RPR VTZ
# ****************************************************************************************************
# 484 484 484 484 484 484
# source= 26 destination= 23 Dates= 15
# RPR IXR
# ****************************************************************************************************
# 484 484 484 484 484 484
# source= 26 destination= 24 Dates= 15
# RPR ATQ
# ****************************************************************************************************
# 484 484 484 484 484 484
# source= 26 destination= 25 Dates= 15
# RPR IXC
# ****************************************************************************************************
# 484 484 484 484 484 484
# source= 26 destination= 27 Dates= 15
# RPR IXE
# ****************************************************************************************************
# 484 484 484 484 484 484
# source= 26 destination= 28 Dates= 15
# RPR IXZ
# ****************************************************************************************************
# 486 486 486 486 486 486
# source= 26 destination= 29 Dates= 15
# RPR TRZ
# ****************************************************************************************************
# 486 486 486 486 486 486
# source= 25 destination= 0 Dates= 16
# IXC DEL
# ****************************************************************************************************
# 488 488 488 488 488 488
# source= 25 destination= 1 Dates= 16
# IXC BOM
# ****************************************************************************************************
# 491 491 491 491 491 491
# source= 25 destination= 2 Dates= 16
# IXC BLR
# ****************************************************************************************************
# 492 492 492 492 492 492
# source= 25 destination= 3 Dates= 16
# IXC HYD
# ****************************************************************************************************
# 493 493 493 493 493 493
# source= 25 destination= 4 Dates= 16
# IXC MAA
# ****************************************************************************************************
# 494 494 494 494 494 494
# source= 25 destination= 5 Dates= 16
# IXC CCU
# ****************************************************************************************************
# 496 496 496 496 496 496
# source= 25 destination= 6 Dates= 16
# IXC COK
# ****************************************************************************************************
# 496 496 496 496 496 496
# source= 25 destination= 7 Dates= 16
# IXC GOI
# ****************************************************************************************************
# 496 496 496 496 496 496
# source= 25 destination= 8 Dates= 16
# IXC PNQ
# ****************************************************************************************************
# 500 500 500 500 500 500
# source= 25 destination= 9 Dates= 16
# IXC GAU
# ****************************************************************************************************
# 500 500 500 500 500 500
# source= 25 destination= 10 Dates= 16
# IXC LKO
# ****************************************************************************************************
# 500 500 500 500 500 500
# source= 25 destination= 11 Dates= 16
# IXC JAI
# ****************************************************************************************************
# 500 500 500 500 500 500
# source= 25 destination= 12 Dates= 16
# IXC PAT
# ****************************************************************************************************
# 500 500 500 500 500 500
# source= 25 destination= 13 Dates= 16
# IXC TRV
# ****************************************************************************************************
# 500 500 500 500 500 500
# source= 25 destination= 14 Dates= 16
# IXC BBI
# ****************************************************************************************************
# 502 502 502 502 502 502
# source= 25 destination= 15 Dates= 16
# IXC CCJ
# ****************************************************************************************************
# 502 502 502 502 502 502
# source= 25 destination= 16 Dates= 16
# IXC IXB
# ****************************************************************************************************
# 505 505 505 505 505 505
# source= 25 destination= 17 Dates= 16
# IXC NAG
# ****************************************************************************************************
# 505 505 505 505 505 505
# source= 25 destination= 18 Dates= 16
# IXC VNS
# ****************************************************************************************************
# 509 509 509 509 509 509
# source= 25 destination= 19 Dates= 16
# IXC IDR
# ****************************************************************************************************
# 513 513 513 513 513 513
# source= 25 destination= 20 Dates= 16
# IXC CJB
# ****************************************************************************************************
# 513 513 513 513 513 513
# source= 25 destination= 21 Dates= 16
# IXC SXR
# ****************************************************************************************************
# 515 515 515 515 515 515
# source= 25 destination= 22 Dates= 16
# IXC VTZ
# ****************************************************************************************************
# 515 515 515 515 515 515
# source= 25 destination= 23 Dates= 16
# IXC IXR
# ****************************************************************************************************
# 515 515 515 515 515 515
# source= 25 destination= 24 Dates= 16
# IXC ATQ
# ****************************************************************************************************
# 515 515 515 515 515 515
# source= 25 destination= 26 Dates= 16
# IXC RPR
# ****************************************************************************************************
# 515 515 515 515 515 515
# source= 25 destination= 27 Dates= 16
# IXC IXE
# ****************************************************************************************************
# 515 515 515 515 515 515
# source= 25 destination= 28 Dates= 16
# IXC IXZ
# ****************************************************************************************************
# 515 515 515 515 515 515
# source= 25 destination= 29 Dates= 16
# IXC TRZ
# ****************************************************************************************************
# 515 515 515 515 515 515
# source= 26 destination= 0 Dates= 16
# RPR DEL
# ****************************************************************************************************
# 517 517 517 517 517 517
# source= 26 destination= 1 Dates= 16
# RPR BOM
# ****************************************************************************************************
# 518 518 518 518 518 518
# source= 26 destination= 2 Dates= 16
# RPR BLR
# ****************************************************************************************************
# 518 518 518 518 518 518
# source= 26 destination= 3 Dates= 16
# RPR HYD
# ****************************************************************************************************
# 519 519 519 519 519 519
# source= 26 destination= 4 Dates= 16
# RPR MAA
# ****************************************************************************************************
# 519 519 519 519 519 519
# source= 26 destination= 5 Dates= 16
# RPR CCU
# ****************************************************************************************************
# 520 520 520 520 520 520
# source= 26 destination= 6 Dates= 16
# RPR COK
# ****************************************************************************************************
# 522 522 522 522 522 522
# source= 26 destination= 7 Dates= 16
# RPR GOI
# ****************************************************************************************************
# 524 524 524 524 524 524
# source= 26 destination= 8 Dates= 16
# RPR PNQ
# ****************************************************************************************************
# 524 524 524 524 524 524
# source= 26 destination= 9 Dates= 16
# RPR GAU
# ****************************************************************************************************
# 524 524 524 524 524 524
# source= 26 destination= 10 Dates= 16
# RPR LKO
# ****************************************************************************************************
# 525 525 525 525 525 525
# source= 26 destination= 11 Dates= 16
# RPR JAI
# ****************************************************************************************************
# 525 525 525 525 525 525
# source= 26 destination= 12 Dates= 16
# RPR PAT
# ****************************************************************************************************
# 525 525 525 525 525 525
# source= 26 destination= 13 Dates= 16
# RPR TRV
# ****************************************************************************************************
# 526 526 526 526 526 526
# source= 26 destination= 14 Dates= 16
# RPR BBI
# ****************************************************************************************************
# 528 528 528 528 528 528
# source= 26 destination= 15 Dates= 16
# RPR CCJ
# ****************************************************************************************************
# 528 528 528 528 528 528
# source= 26 destination= 16 Dates= 16
# RPR IXB
# ****************************************************************************************************
# 528 528 528 528 528 528
# source= 26 destination= 17 Dates= 16
# RPR NAG
# ****************************************************************************************************
# 528 528 528 528 528 528
# source= 26 destination= 18 Dates= 16
# RPR VNS
# ****************************************************************************************************
# 528 528 528 528 528 528
# source= 26 destination= 19 Dates= 16
# RPR IDR
# ****************************************************************************************************
# 528 528 528 528 528 528
# source= 26 destination= 20 Dates= 16
# RPR CJB
# ****************************************************************************************************
# 528 528 528 528 528 528
# source= 26 destination= 21 Dates= 16
# RPR SXR
# ****************************************************************************************************
# 529 529 529 529 529 529
# source= 26 destination= 22 Dates= 16
# RPR VTZ
# ****************************************************************************************************
# 529 529 529 529 529 529
# source= 26 destination= 23 Dates= 16
# RPR IXR
# ****************************************************************************************************
# 531 531 531 531 531 531
# source= 26 destination= 24 Dates= 16
# RPR ATQ
# ****************************************************************************************************
# 531 531 531 531 531 531
# source= 26 destination= 25 Dates= 16
# RPR IXC
# ****************************************************************************************************
# 531 531 531 531 531 531
# source= 26 destination= 27 Dates= 16
# RPR IXE
# ****************************************************************************************************
# 531 531 531 531 531 531
# source= 26 destination= 28 Dates= 16
# RPR IXZ
# ****************************************************************************************************
# 533 533 533 533 533 533
# source= 26 destination= 29 Dates= 16
# RPR TRZ
# ****************************************************************************************************
# 533 533 533 533 533 533

# %%
data = pd.DataFrame(
    {'Price':price,
     'Cities':cities,
     'departure_time':departure_time,
     'arrival_time':arrival_time, 
     'layeover':via,
     'Airline':airline
    })

# %%
data
# Out:
#        Price                              Cities departure_time arrival_time  \
# 0      4,442    Chandigarh to New Delhi , 01 May          15:25        16:30
# 1      4,442    Chandigarh to New Delhi , 01 May          18:50        19:55
# 2      9,132    Chandigarh to Hyderabad , 01 May          18:50        22:55
# 3      9,132  Chandigarh to Bhubaneswar , 01 May          15:25        19:55
# 4      8,978       Chandigarh to Indore , 01 May          15:25        19:55
# ..       ...                                 ...            ...          ...
# 528    9,114         Raipur to Srinagar , 16 May          08:55        13:10
# 529    9,674           Raipur to Ranchi , 16 May          08:55        19:40
# 530    9,674           Raipur to Ranchi , 16 May          20:20        08:20
# 531   14,602       Raipur to Port Blair , 16 May          20:20        11:20
# 532   15,554       Raipur to Port Blair , 16 May          08:55        11:20
#
#                          layeover  Airline
# 0                        Non stop  Vistara
# 1                        Non stop  Vistara
# 2            1 stop via New Delhi  Vistara
# 3            1 stop via New Delhi  Vistara
# 4            1 stop via New Delhi  Vistara
# ..                            ...      ...
# 528          1 stop via New Delhi  Vistara
# 529          1 stop via New Delhi  Vistara
# 530          1 stop via New Delhi  Vistara
# 531  2 stop via New Delhi,Kolkata  Vistara
# 532  2 stop via New Delhi,Kolkata  Vistara
#
# [533 rows x 6 columns]

# %%
print(len(departure_time), len(price),len(cities),len(arrival_time),len(via),len(airline))
# Out:
# 533 533 533 533 533 533

# %%
data.to_csv("25-27-data-pe-may.csv")

# %%
data_1=pd.read_csv("0-5.csv")
data_2=pd.read_csv("0-5_data.csv")

# %%
data_1.shape

# %%
data_2.shape

# %%
data_1=data_1.append(data_2)

# %%
data_1=data_1.drop_duplicates(keep="first")

# %%
data_1.shape

# %%
data_1.to_csv("0-5final.csv")

# %%
print(len(price),len(cities),len(departure_time),len(arrival_time),len(via),len(airline))

# %%
cities

# %%
soup.find_all('p')

# %%
for i in codes["Code"]:
    for j in codes["Code"]:
        print(i,j)

# %%
url="https://www.makemytrip.com/flight/search?itinerary=DEL-BOM-15/04/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&cabinClass=E&ccde=IN&lang=eng"
driver = webdriver.Chrome("C:/chromedriver.exe")
driver.get(url)
soup=BeautifulSoup(driver.page_source, 'lxml')

# %%
soup.find_all('ul')#,attrs={"class":"guestCounter"})

# %%
price_info=soup.find_all('p',attrs={'class': 'blackText fontSize18 blackFont'})

# %%
price=[]
for j,i in enumerate(price_info):
    if j<10:
        a=str(i)
        price.append(a[43:len(a)-4])
len(price)

# %%
s='<p class="blackText fontSize18 blackFont">₹'
len(s)

# %%
flights_info=soup.find_all('p',attrs={'class': 'flightDetailsHead'})
cities=[]
k=0
for i,j in enumerate(flights_info):
    if i<=10:
        k=str(j)
        if len(k)>45:
            cities.append(k[29:(len(k)-4)])

# %%
cities

# %%
time_info=soup.find_all('p',attrs={'class':"blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"})
departure_time=[]
arrival_time=[]

for i,j in enumerate(b):
    k=str(j)
    if (i%2==0):
        departure_time.append(k[82:87])
    else:
        arrival_time.append(k[82:87])

# %%
layover_info=soup.find_all('p',attrs={'class': 'flightsLayoverInfo'})

# %%
via=[]
for i in c:
    via1=[]
    k=str(i)
    via1.append(k[30:len(k)-4])
    via.append(via1)

# %%
len(via)

# %%
airline_info=soup.find_all('span',attrs={'class': 'boldFont blackText airlineName'})
airline=[]
for i,j in enumerate(d):
    k=str(j)
    airline.append(k[45:len(k)-7])

len(airline)

# %%
s="<span class='boldFont blackText airlineName'>"
len(s)

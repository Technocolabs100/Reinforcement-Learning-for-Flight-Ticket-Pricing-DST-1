# %% [markdown]
# ### Project on Reinforcement learning on Flight price

# %%
#Load the libraries that are required for the project
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import r2_score

#import plotly.express as px

# %%
#Load the data in to the local machine
df=pd.read_csv("final_dataset.csv")
df.head()
# Out:
#    Price  Optimal_hr  Airline Cabin  Dept_city  Dept_date Dept_month  \
# 0   6159           5  Vistara    PE  New Delhi         20        Apr
# 1   6159          11  Vistara    PE  New Delhi         20        Apr
# 2   6159          12  Vistara    PE  New Delhi         20        Apr
# 3   6159           8  Vistara    PE  New Delhi         20        Apr
# 4   6159          13  Vistara    PE  New Delhi         20        Apr
#
#   arrival_city  stops layover_cities    Departure_Date      Arrival_Date  \
# 0      Mumbai       0       No Stops  20-04-2021 09:30  20-04-2021 11:40
# 1      Mumbai       0       No Stops  20-04-2021 15:30  20-04-2021 17:40
# 2      Mumbai       0       No Stops  20-04-2021 16:55  20-04-2021 19:05
# 3      Mumbai       0       No Stops  20-04-2021 12:45  20-04-2021 15:00
# 4      Mumbai       0       No Stops  20-04-2021 17:45  20-04-2021 20:05
#
#    duration  weekday day_name  dept_hours  arrival_hours Dept_flights_time  \
# 0     130.0        1  Tuesday           9             11    Morning_flight
# 1     130.0        1  Tuesday          15             17  Afternoon_flight
# 2     130.0        1  Tuesday          16             19    Evening_flight
# 3     135.0        1  Tuesday          12             15  Afternoon_flight
# 4     140.0        1  Tuesday          17             20    Evening_flight
#
#   arrival_flights_time
# 0     Afternoon_flight
# 1       Evening_flight
# 2       Evening_flight
# 3     Afternoon_flight
# 4       Evening_flight

# %%
df.tail()
# Out:
#         Price  Optimal_hr  Airline Cabin Dept_city  Dept_date Dept_month  \
# 315980   9114           4  Vistara    PE    Raipur         16        May
# 315981   9674           4  Vistara    PE    Raipur         16        May
# 315982   9674          16  Vistara    PE    Raipur         16        May
# 315983  14602          16  Vistara    PE    Raipur         16        May
# 315984  15554           4  Vistara    PE    Raipur         16        May
#
#        arrival_city  stops     layover_cities       Departure_Date  \
# 315980    Srinagar       1          New Delhi  2021-05-16 08:55:00
# 315981      Ranchi       1          New Delhi  2021-05-16 08:55:00
# 315982      Ranchi       1          New Delhi  2021-05-16 20:20:00
# 315983  Port Blair       2  New Delhi,Kolkata  2021-05-16 20:20:00
# 315984  Port Blair       2  New Delhi,Kolkata  2021-05-16 08:55:00
#
#                Arrival_Date  duration  weekday day_name  dept_hours  \
# 315980  2021-05-16 13:10:00     255.0        6   Sunday           8
# 315981  2021-05-16 19:40:00     645.0        6   Sunday           8
# 315982  2021-05-16 08:20:00     720.0        6   Sunday          20
# 315983  2021-05-16 11:20:00     900.0        6   Sunday          20
# 315984  2021-05-16 11:20:00     145.0        6   Sunday           8
#
#         arrival_hours Dept_flights_time arrival_flights_time
# 315980             13    Morning_flight     Afternoon_flight
# 315981             19    Morning_flight       Evening_flight
# 315982              8    Evening_flight       Morning_flight
# 315983             11    Evening_flight     Afternoon_flight
# 315984             11    Morning_flight     Afternoon_flight

# %% [markdown]
# ### Let's do some EDA

# %%
class DataFrame_Info():
    def __init__(self):
        print("Attribute information")
    
    def Attribute_information(self,df):
        """
        This method give us the basic information of all the attributes like count of attributes,number of rows & columns,numerical attributes and categorical attributes and so on
        """
        
        data_info=pd.DataFrame(columns=['No of observation',
                                       'No of variables',
                                       'No of Numerical variables',
                                       'No of Factor variables',
                                       'No of Categorival variables',
                                       'No of Logical variables',
                                       'No of Date Variables',
                                       'No of zero variance variables'])
        
        data_info.loc[0,'No of observation']=df.shape[0]

        data_info.loc[0,'No of variables']=df.shape[1]
        
        data_info.loc[0,'No of Numerical variables']=df._get_numeric_data().shape[1]
        
        data_info.loc[0,'No of Factor variables']=df.select_dtypes(include='category').shape[1]
        
        data_info.loc[0,'No of Categorival variables']=df.select_dtypes(include='object').shape[1]
        
        data_info.loc[0,'No of Logical variables']=df.select_dtypes(include='bool').shape[1]
        
        data_info.loc[0,'No of Date Variables']=df.select_dtypes(include='datetime64').shape[1]
        
        data_info.loc[0,'No of zero variance variables']=df.loc[:,df.apply(pd.Series.nunique)==1].shape[1]
        
        data_info=data_info.transpose()
        
        data_info.columns=['value']
        
        
        
        return data_info
    
    def __get_missing_values(self,data):
        
        """
        It is a private method ,so it cannot accesed by object outsid ethe class.This function will give us a basic information like count of missing values
        """
        
        #Getting sum of missing values for each feature
        missing_values=data.isnull().sum()
        #Feature missing values are ssorted from few to many
        missing_values.sort_values(ascending=False,inplace=True)
        #get the missing values
        return missing_values
    
    def Agg_Tabulation(self,data):
        """
        This method is a extension of additional inforamtion like about the data like Entrophy value,missing value percentage and some observations
        """
        
        print('='*100)
        print('Aggrgation of Table')
        
        table=pd.DataFrame(data.dtypes,columns=['dtypes'])
        table1=pd.DataFrame(data.columns,columns=['Names'])
        table=table.reset_index()
        table=table.rename(columns={'index':'Name'})
        table['No of missing']=data.isnull().sum().values
        table['No of unique']=data.nunique().values
        table['Percent of missing']=((data.isnull().sum().values)/(data.shape[0]))*100
        table['First Observation']=data.loc[0].values
        table['Second observation']=data.loc[1].values
        table['Third Observation']=data.loc[2].values
        
    
        return table
        
        
        print('*'*100)
        print('Interquartile Range')
    def _iqr(self,x):
        """
        It is a private method return you a interquartile range
        """
            
        return x.quantile(q=0.75)-x.quantile(q=0.25)
        
    def __outlier_count(self,x):
        """
        It is a private method which return you a outliers present in a interquartile range
        """
        upper_out=x.quantile(q=0.75)+1.5 * self._iqr(x)
        lower_out=x.quantile(q=0.25)-1.5 * self._iqr(x)
            
        return len(x[x > upper_out])+len(x[x < lower_out])
    def num_count_summary(self,df):
        """
        This method which returns you basci information about Numerica variable like Positive values,Negitive Vlues,Unique Count,Zero count positive and negitive,infiniyt-count and count of outliers
        """
            
        df_num=df._get_numeric_data()
        data_info_num=pd.DataFrame()
        i=0
        for c in df_num.columns:
            data_info_num.loc[c,'Negitive values']=df_num[df_num[c] < 0].shape[0]
            data_info_num.loc[c,'Positive values']=df_num[df_num[c] > 0].shape[0]
            data_info_num.loc[c,'Zero values']=df_num[df_num[c]== 0].shape[0]
            data_info_num.loc[c,'Unique_count']=len(df_num[c].unique())
            data_info_num.loc[c,'Negitive_infinity_count']=df_num[df_num[c]== -np.inf].shape[0]
            data_info_num.loc[c,'Positive_infinity_count']=df_num[df_num[c]== np.inf].shape[0]
            data_info_num.loc[c,'Percentage of miisning values']=df_num[df_num[c].isnull()].shape[0]/df_num.shape[0]
            data_info_num.loc[c,'Count of outliers']=self.__outlier_count(df_num[c])
            i= i+1
        return data_info_num
    def statstical_summary(self,df):
        """
        This method which return you a various percentile of the data including count and mean
        """
        df_num=df._get_numeric_data()
        data_stat_num=pd.DataFrame()
            
        try:
            data_stat_num=pd.concat([df_num.describe().transpose(),
                                        pd.DataFrame(df_num.quantile(q=0.1)),
                                        pd.DataFrame(df_num.quantile(q=0.90)),
                                        pd.DataFrame(df_num.quantile(q=0.95))],axis=1)
            data_stat_num.columns=['count','mean','std','min','25%','50%','75%','max','10%','90%','95%']
        except:
            pass
        return data_stat_num

# %%
#Intialize the dataframe object
dataframe=DataFrame_Info()
# Out:
# Attribute information

# %%
dataframe.Agg_Tabulation(df)
# Out:
# ====================================================================================================
# Aggrgation of Table
#                     Name   dtypes  No of missing  No of unique  \
# 0                  Price    int64              0         20523
# 1             Optimal_hr    int64              0            24
# 2                Airline   object              0            46
# 3                  Cabin   object              0             3
# 4              Dept_city   object              0            30
# 5              Dept_date    int64              0            30
# 6             Dept_month   object              0             2
# 7           arrival_city   object              0            30
# 8                  stops    int64              0             7
# 9         layover_cities   object              0          1032
# 10        Departure_Date   object              0          8087
# 11          Arrival_Date   object              0          9476
# 12              duration  float64              0           288
# 13               weekday    int64              0             7
# 14              day_name   object              0             7
# 15            dept_hours    int64              0            24
# 16         arrival_hours    int64              0            24
# 17     Dept_flights_time   object              0             4
# 18  arrival_flights_time   object              0             4
#
#     Percent of missing First Observation Second observation Third Observation
# 0                  0.0              6159               6159              6159
# 1                  0.0                 5                 11                12
# 2                  0.0           Vistara            Vistara           Vistara
# 3                  0.0                PE                 PE                PE
# 4                  0.0         New Delhi          New Delhi         New Delhi
# 5                  0.0                20                 20                20
# 6                  0.0               Apr                Apr               Apr
# 7                  0.0           Mumbai             Mumbai            Mumbai
# 8                  0.0                 0                  0                 0
# 9                  0.0          No Stops           No Stops          No Stops
# 10                 0.0  20-04-2021 09:30   20-04-2021 15:30  20-04-2021 16:55
# 11                 0.0  20-04-2021 11:40   20-04-2021 17:40  20-04-2021 19:05
# 12                 0.0               130                130               130
# 13                 0.0                 1                  1                 1
# 14                 0.0           Tuesday            Tuesday           Tuesday
# 15                 0.0                 9                 15                16
# 16                 0.0                11                 17                19
# 17                 0.0    Morning_flight   Afternoon_flight    Evening_flight
# 18                 0.0  Afternoon_flight     Evening_flight    Evening_flight

# %%
dataframe.Attribute_information(df)
# Out:
#                                 value
# No of observation              315985
# No of variables                    19
# No of Numerical variables           8
# No of Factor variables              0
# No of Categorival variables        11
# No of Logical variables             0
# No of Date Variables                0
# No of zero variance variables       0

# %%
dataframe.num_count_summary(df)
# Out:
#                Negitive values  Positive values  Zero values  Unique_count  \
# Price                      0.0         315985.0          0.0       20523.0
# Optimal_hr                 0.0         314873.0       1112.0          24.0
# Dept_date                  0.0         315985.0          0.0          30.0
# stops                      0.0         286949.0      29036.0           7.0
# duration                   0.0         315811.0        174.0         288.0
# weekday                    0.0         276133.0      39852.0           7.0
# dept_hours                 0.0         314871.0       1114.0          24.0
# arrival_hours              0.0         312124.0       3861.0          24.0
#
#                Negitive_infinity_count  Positive_infinity_count  \
# Price                              0.0                      0.0
# Optimal_hr                         0.0                      0.0
# Dept_date                          0.0                      0.0
# stops                              0.0                      0.0
# duration                           0.0                      0.0
# weekday                            0.0                      0.0
# dept_hours                         0.0                      0.0
# arrival_hours                      0.0                      0.0
#
#                Percentage of miisning values  Count of outliers
# Price                                    0.0             6619.0
# Optimal_hr                               0.0                0.0
# Dept_date                                0.0                0.0
# stops                                    0.0           100397.0
# duration                                 0.0             6314.0
# weekday                                  0.0                0.0
# dept_hours                               0.0                0.0
# arrival_hours                            0.0                0.0

# %%
dataframe.statstical_summary(df)
# Out:
#                   count          mean           std     min     25%     50%  \
# Price          315985.0  17927.651512  19819.471740  1579.0  5072.0  7136.0
# Optimal_hr     315985.0      8.914271      5.148739     0.0     4.0     8.0
# Dept_date      315985.0     16.055683      8.435804     1.0     9.0    16.0
# stops          315985.0      1.188841      0.678200     0.0     1.0     1.0
# duration       315985.0    557.704163    324.547822     0.0   335.0   495.0
# weekday        315985.0      3.199744      1.982126     0.0     1.0     3.0
# dept_hours     315985.0     12.579471      5.113899     0.0     8.0    12.0
# arrival_hours  315985.0     14.608807      5.483142     0.0    10.0    15.0
#
#                    75%       max     10%      90%      95%
# Price          30336.0  122450.0  3942.0  51712.0  59917.0
# Optimal_hr        13.0      23.0     3.0     16.0     18.0
# Dept_date         23.0      30.0     4.0     28.0     29.0
# stops              1.0       6.0     1.0      2.0      2.0
# duration         735.0    1435.0   155.0   1060.0   1230.0
# weekday            5.0       6.0     0.0      6.0      6.0
# dept_hours        17.0      23.0     6.0     20.0     21.0
# arrival_hours     19.0      23.0     7.0     22.0     22.0

# %%
#load the categorical data in to the "cat_data" and get the patters inside of the categorical data
cat_data=df.select_dtypes(include="object")
cat_data.head()
# Out:
#    Airline Cabin  Dept_city Dept_month arrival_city layover_cities  \
# 0  Vistara    PE  New Delhi        Apr      Mumbai        No Stops
# 1  Vistara    PE  New Delhi        Apr      Mumbai        No Stops
# 2  Vistara    PE  New Delhi        Apr      Mumbai        No Stops
# 3  Vistara    PE  New Delhi        Apr      Mumbai        No Stops
# 4  Vistara    PE  New Delhi        Apr      Mumbai        No Stops
#
#      Departure_Date      Arrival_Date day_name Dept_flights_time  \
# 0  20-04-2021 09:30  20-04-2021 11:40  Tuesday    Morning_flight
# 1  20-04-2021 15:30  20-04-2021 17:40  Tuesday  Afternoon_flight
# 2  20-04-2021 16:55  20-04-2021 19:05  Tuesday    Evening_flight
# 3  20-04-2021 12:45  20-04-2021 15:00  Tuesday  Afternoon_flight
# 4  20-04-2021 17:45  20-04-2021 20:05  Tuesday    Evening_flight
#
#   arrival_flights_time
# 0     Afternoon_flight
# 1       Evening_flight
# 2       Evening_flight
# 3     Afternoon_flight
# 4       Evening_flight

# %%
#Check the values in each variables inside of the categorical data
def value_cat(var,cat_data):
  print("*"*15+var+"*"*15)
  print(cat_data[var].value_counts())

# %%
for _ in cat_data.columns:
  value_cat(_,cat_data)
# Out:
# ***************Airline***************
# IndiGo                        124632
# Air India                      72560
# Vistara                        46562
# Go Air                         19705
# Spicejet                       15066
# AirAsia                         9565
# Vistara, Air India              3421
# Air India, IndiGo               3005
# Go Air, IndiGo                  2782
# Air India, Vistara              2703
# Spicejet, IndiGo                2570
# IndiGo, Go Air                  2370
# IndiGo, Air India               1765
# AirAsia, IndiGo                 1481
# IndiGo, Spicejet                1455
# IndiGo, AirAsia                 1308
# Vistara, IndiGo                 1224
# IndiGo, Vistara                  697
# Air India, Go Air                606
# Air India, AirAsia               282
# Go Air, Air India                263
# Vistara, Go Air                  232
# Spicejet, Go Air                 211
# Air India, Spicejet              190
# Go Air, Spicejet                 181
# Spicejet, Air India              135
# AirAsia, Spicejet                126
# AirAsia, Go Air                  124
# AirAsia, Air India               112
# Spicejet, AirAsia                110
# Go Air, Vistara                  109
# Vistara, AirAsia                  92
# Go Air, AirAsia                   74
# Spicejet, Vistara                 70
# TruJet                            52
# AirAsia, Vistara                  47
# Vistara, Spicejet                 21
# flybig                            21
# flybig, Spicejet                  20
# flybig, Go Air                    14
# flybig, IndiGo                     8
# IndiGo, Air India Express          5
# flybig, Air India                  4
# Air India Express                  3
# Vistara, Air India Express         1
# flybig, Vistara                    1
# Name: Airline, dtype: int64
# ***************Cabin***************
# E     185989
# B     113127
# PE     16869
# Name: Cabin, dtype: int64
# ***************Dept_city***************
# Kolkata               16016
# Mumbai                15638
# New Delhi             15500
# Bengaluru             14682
# Hyderabad             14117
# Goa                   13990
# Amritsar              13726
# Kochi                 13481
# Chennai               13336
# Srinagar              13287
# Guwahati              12890
# Patna                 12183
# Lucknow               12172
# Ranchi                11978
# Port Blair            11659
# Bhubaneswar           11562
# Visakhapatnam         11420
# Jaipur                 9866
# Mangalore              9774
# Coimbatore             9757
# Thiruvananthapuram     9256
# Raipur                 8205
# Pune                   7825
# Chandigarh             7563
# Varanasi               5535
# Bagdogra               5309
# Indore                 5190
# Nagpur                 4424
# Tiruchirappalli        3532
# Kozhikode              2112
# Name: Dept_city, dtype: int64
# ***************Dept_month***************
# Apr    165664
# May    150321
# Name: Dept_month, dtype: int64
# ***************arrival_city***************
# New Delhi              14924
# Mumbai                 14585
# Bengaluru              14093
# Chennai                13949
# Kolkata                13851
# Hyderabad              13659
# Goa                    12254
# Bhubaneswar            11854
# Amritsar               11721
# Lucknow                11372
# Patna                  11296
# Kochi                  11219
# Guwahati               11009
# Varanasi               10819
# Raipur                 10556
# Chandigarh             10546
# Indore                 10419
# Srinagar               10263
# Ranchi                  9852
# Nagpur                  9798
# Port Blair              9770
# Visakhapatnam           9650
# Bagdogra                9433
# Jaipur                  9178
# Thiruvananthapuram      8881
# Coimbatore              8714
# Mangalore               8119
# Pune                    6600
# Tiruchirappalli         4269
# Kozhikode               3332
# Name: arrival_city, dtype: int64
# ***************layover_cities***************
# New Delhi                                 93626
# Bengaluru                                 32752
# Mumbai                                    31093
# No Stops                                  29036
# Chennai                                   19129
#                                           ...
# Bengaluru,Nagpur                              1
# Raipur,New Delhi,Ahmedabad                    1
# Hyderabad,Kolkata,Mumbai,Chennai              1
# Thiruvananthapuram,Kochi                      1
# Visakhapatnam,Mumbai,Bengaluru,Kolkata        1
# Name: layover_cities, Length: 1032, dtype: int64
# ***************Departure_Date***************
# 30-04-2021 08:55       282
# 23-04-2021 08:55       250
# 18-04-2021 15:25       249
# 25-04-2021 08:55       244
# 28-04-2021 08:55       242
#                       ...
# 12-05-2021 02:30         1
# 29-04-2021 21:40         1
# 08-05-2021 02:40         1
# 06-05-2021 02:30         1
# 2021-05-12 12:20:00      1
# Name: Departure_Date, Length: 8087, dtype: int64
# ***************Arrival_Date***************
# 22-04-2021 09:05       205
# 24-04-2021 22:20       203
# 24-04-2021 08:25       195
# 20-04-2021 08:25       194
# 25-04-2021 08:25       193
#                       ...
# 2021-05-13 15:55:00      1
# 2021-05-01 21:10:00      1
# 2021-05-10 20:30:00      1
# 22-04-2021 01:50         1
# 28-04-2021 05:10         1
# Name: Arrival_Date, Length: 9476, dtype: int64
# ***************day_name***************
# Friday       53583
# Saturday     50475
# Sunday       49044
# Thursday     43794
# Monday       39852
# Tuesday      39756
# Wednesday    39481
# Name: day_name, dtype: int64
# ***************Dept_flights_time***************
# Morning_flight      124517
# Afternoon_flight     91196
# Evening_flight       69214
# Night_flight         31058
# Name: Dept_flights_time, dtype: int64
# ***************arrival_flights_time***************
# Evening_flight      105086
# Afternoon_flight     79943
# Morning_flight       75495
# Night_flight         55461
# Name: arrival_flights_time, dtype: int64

# %%
columns_to_do_plot=cat_data[['Airline', 'Cabin', 'Dept_city', 'Dept_month', 'arrival_city','day_name','Dept_flights_time', 'arrival_flights_time']]

# %%
#Visualize the categories with the help of bar plot
import random
for i in columns_to_do_plot.columns:
  for j in random.choices(['summer','viridis','Set1','Set2','Set3','BuPu','inferno']):
    plt.figure(figsize=(15,7))
    sns.set_style('darkgrid')
    g=sns.countplot(x=i,data=cat_data,palette=j)
    g.set_xlabel(i,fontsize=18)
    g.set_xticklabels(g.get_xticklabels(),rotation=90)
    g.set_title(i,fontsize=20)
    plt.show()

# %%
#Compare the each category in categorical column with the "Price columns" 
#Get the top 10 flights to compare with the Price column
top_20=df["Airline"].value_counts()[:20]
plt.figure(figsize=(10,12))
gv=sns.barplot(y=top_20.index,x=top_20.values,data=df,palette="CMRmap")
plt.title("Top 20 Airline w/r to Prices",fontsize=19)
plt.show()

# %% [markdown]
# The Flight price of the indigo airline is very high as compared to the other airline

# %%
def compare_with_tar(var,columns_to_do_plot,df):
  plt.style.use('fivethirtyeight')
  sns.catplot(x=var,y='Price',data=df,palette="viridis",aspect=2,height=5,kind='box')
  plt.title(var+"vs Price")
  plt.xticks(rotation=90)
  plt.show()

# %%
compare_with_tar("day_name",columns_to_do_plot,df)

# %%
#Check Stops and dept flight time with the price
gv=df.groupby(["stops","Dept_flights_time"])[["Price"]].mean()
print(f"The flight price of the '{gv['Price'].idxmax()[1]}' is comparitvely higher with the No stops of '{gv['Price'].idxmax()[0]}' and the flight price is '{gv['Price'].max()}'",'\n')
print(f"The flight price of the '{gv['Price'].idxmin()[1]}' is comparitvely lower and the No of stops are '{gv['Price'].idxmin()[0]}' and the flight price is '{gv['Price'].min()}'")
# Out:
# The flight price of the 'Afternoon_flight' is comparitvely higher with the No stops of '6' and the flight price is '90117.0'
#
# The flight price of the 'Night_flight' is comparitvely lower and the No of stops are '0' and the flight price is '7587.08090349076'

# %%
#Check day wise price of the flight
day_wis=df.groupby("day_name")["Price"].mean().sort_values(ascending=False)
plt.figure(figsize=(10,8))
plt.pie(day_wis.values,labels=day_wis.index,shadow=True,startangle=90,autopct="%1.1f%%",explode=[0.1,0.1,0,0,0,0,0])
plt.title("Day wise Price variations on the flight",fontsize=20)
plt.show()

# %% [markdown]
# As we can see the flight price on the Saturday and sunday is comparitivle higher

# %%
vg=df.groupby("Optimal_hr")[["Price"]].mean()
vg.plot.bar(color=sns.color_palette("viridis",18),figsize=(12,6))
plt.title("Optimal hour w/r to Price",fontsize=20)
plt.show()

# %% [markdown]
# The Price at Optimal_hr(23) is relatively higher and lower in Optimal_hr (20)

# %%
#Get the which arrival city highest and lowest flight price
arr=df.groupby("arrival_city")["Price"].mean()
arr.plot.bar(color=sns.color_palette("Set2",8),figsize=(12,6))
plt.title("Arrival city w/r to Price",fontsize=19)
plt.show()

# %%
#Get the which dept city has highest flight price
arr1=df.groupby("Dept_city")["Price"].mean()
arr1.plot.bar(color=sns.color_palette("Set1",8),figsize=(12,6))
plt.title("Departure city w.r to Price",fontsize=19)
plt.show()

# %%
#Check the How many hours if a flight take to departure will affect on a price
debt=df.groupby("Airline")["dept_hours"].mean().sort_values(ascending=False)
debt.plot.bar(color=sns.color_palette("summer"),figsize=(12,7))
plt.title("Depature hour effects on flight price",fontsize=20)
plt.show()

# %%
#Check In which day in which flight is getting higher price
sns.catplot(x='day_name',y='Price',hue='Dept_flights_time',kind='box',data=df,height=7,aspect=3)
plt.title("In which day in which time flights is getting higher price",fontsize=20)
plt.show()

# %%
#Check the distribution of the Price column
fig,ax=plt.subplots(1,2,figsize=(13,7))
df["Price"].hist(ax=ax[1])
sns.boxplot(x=df['Price'],ax=ax[0])
# Out:
# <AxesSubplot:xlabel='Price'>

# %% [markdown]
# We can observe that our price column show's right skewness we need to handle by using feature transformation techniques else it will impact on our model perfromance, most of the Flight price data is falling on Left side show's right skewness. also our price column has so many outliers we need to take care of that by using IQR method.

# %%
#Whcih airline takes high duration with respect to the price
ddr=df.groupby("Airline")[["duration","Price"]].mean()
ddr.plot.bar(figsize=(15,7))
# Out:
# <AxesSubplot:xlabel='Airline'>

# %%
#Finding and plotting the correlation matrix for top20 features

cmap=sns.diverging_palette(220,10,as_cmap=True)
plt.figure(figsize=(15,15))

corr=df.corr()

#Genrate a mask triangle for a upper traingle
mask=np.triu(np.ones_like(corr,dtype=np.bool))

g=sns.heatmap(corr,annot=True,mask=mask,vmax=0.3,center=0,square=True,cmap=cmap,linewidths=0.05)
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# As we can see the correlation matrix
# 1. Stops-Price is moderatly correlated (0.47)
# 2. Duration-Price is Higly Correlated (0.41)
# 3. Dept_hrs-Optimal_hr is Strongly correlated (0.85)
# 4. Stops-Duration is moderatly correlated (0.57)

# %%
#Our "Airline" data column has two categories such as departure flight and return flight so we need to take that those as two features instead of one variable
recent=pd.DataFrame(df['Airline'].apply(lambda x: x.split(',')).values.tolist(),columns=['Airline_1','Airline_2'])
recent_1=recent["Airline_1"]
recent_1
# Out:
# 0         Vistara
# 1         Vistara
# 2         Vistara
# 3         Vistara
# 4         Vistara
#            ...
# 315980    Vistara
# 315981    Vistara
# 315982    Vistara
# 315983    Vistara
# 315984    Vistara
# Name: Airline_1, Length: 315985, dtype: object

# %%
#Fill the null values with the another column such as "Airline_1"
fill_val=recent["Airline_2"].fillna(recent["Airline_1"])
#After handling null values in the airline column concatinate the airline column with the main dataframe
df_new=pd.concat([df,recent_1,fill_val],axis=1)
df_new.head()
# Out:
#    Price  Optimal_hr  Airline Cabin  Dept_city  Dept_date Dept_month  \
# 0   6159           5  Vistara    PE  New Delhi         20        Apr
# 1   6159          11  Vistara    PE  New Delhi         20        Apr
# 2   6159          12  Vistara    PE  New Delhi         20        Apr
# 3   6159           8  Vistara    PE  New Delhi         20        Apr
# 4   6159          13  Vistara    PE  New Delhi         20        Apr
#
#   arrival_city  stops layover_cities  ...      Arrival_Date duration  weekday  \
# 0      Mumbai       0       No Stops  ...  20-04-2021 11:40    130.0        1
# 1      Mumbai       0       No Stops  ...  20-04-2021 17:40    130.0        1
# 2      Mumbai       0       No Stops  ...  20-04-2021 19:05    130.0        1
# 3      Mumbai       0       No Stops  ...  20-04-2021 15:00    135.0        1
# 4      Mumbai       0       No Stops  ...  20-04-2021 20:05    140.0        1
#
#    day_name dept_hours  arrival_hours  Dept_flights_time arrival_flights_time  \
# 0   Tuesday          9             11     Morning_flight     Afternoon_flight
# 1   Tuesday         15             17   Afternoon_flight       Evening_flight
# 2   Tuesday         16             19     Evening_flight       Evening_flight
# 3   Tuesday         12             15   Afternoon_flight     Afternoon_flight
# 4   Tuesday         17             20     Evening_flight       Evening_flight
#
#   Airline_1 Airline_2
# 0   Vistara   Vistara
# 1   Vistara   Vistara
# 2   Vistara   Vistara
# 3   Vistara   Vistara
# 4   Vistara   Vistara
#
# [5 rows x 21 columns]

# %%
#Our new airline columns data look like
fig,ax=plt.subplots(1,2,figsize=(15,6))
air1=df_new["Airline_1"].value_counts()
air2=df_new["Airline_2"].value_counts()
air1.plot.bar(color=sns.color_palette("bwr"),ax=ax[0],label="Departure Flights")
air2.plot.bar(color=sns.color_palette("magma"),ax=ax[1])
plt.title("Destination_flights",fontsize=20)
plt.suptitle("Airline",fontsize=20)
plt.show()

# %%
#Replace the some values in the Airline_1 columns
df_new['Airline_1'].replace("Air India Express","Air India",inplace=True)

# %%
df_new["Airline_2"].replace([" Air India Express","Air India Express"," Air India"],"Air India",inplace=True)

# %%
df_new["Airline_2"].replace([" AirAsia"," Go Air"," Vistara"," Spicejet"," IndiGo"],["AirAsia","Go Air","Vistara","Spicejet","IndiGo"],inplace=True)

# %%
#Extract the date and month from the date columns
df_new["Day_of_Dep"]=pd.to_datetime(df_new['Departure_Date']).dt.day
df_new["Month_of_Dep"]=pd.to_datetime(df_new["Departure_Date"]).dt.month
df_new["Day_of_Arr"]=pd.to_datetime(df_new["Arrival_Date"]).dt.day
df_new["month_of_Arr"]=pd.to_datetime(df_new["Arrival_Date"]).dt.month

# %%
#Let's drop the some unwanted columns that doesn't require during model building
df_1=df_new.copy()
df_1.drop(labels=["Airline","Dept_date","layover_cities","Departure_Date","Arrival_Date"],axis=1,inplace=True)

# %%
df_1.head()
# Out:
#    Price  Optimal_hr Cabin  Dept_city Dept_month arrival_city  stops  \
# 0   6159           5    PE  New Delhi        Apr      Mumbai       0
# 1   6159          11    PE  New Delhi        Apr      Mumbai       0
# 2   6159          12    PE  New Delhi        Apr      Mumbai       0
# 3   6159           8    PE  New Delhi        Apr      Mumbai       0
# 4   6159          13    PE  New Delhi        Apr      Mumbai       0
#
#    duration  weekday day_name  dept_hours  arrival_hours Dept_flights_time  \
# 0     130.0        1  Tuesday           9             11    Morning_flight
# 1     130.0        1  Tuesday          15             17  Afternoon_flight
# 2     130.0        1  Tuesday          16             19    Evening_flight
# 3     135.0        1  Tuesday          12             15  Afternoon_flight
# 4     140.0        1  Tuesday          17             20    Evening_flight
#
#   arrival_flights_time Airline_1 Airline_2  Day_of_Dep  Month_of_Dep  \
# 0     Afternoon_flight   Vistara   Vistara          20             4
# 1       Evening_flight   Vistara   Vistara          20             4
# 2       Evening_flight   Vistara   Vistara          20             4
# 3     Afternoon_flight   Vistara   Vistara          20             4
# 4       Evening_flight   Vistara   Vistara          20             4
#
#    Day_of_Arr  month_of_Arr
# 0          20             4
# 1          20             4
# 2          20             4
# 3          20             4
# 4          20             4

# %% [markdown]
# ### As of Now i converted all categorical values in to the numerical with the help of label encoder based on the model perfromance we can check again and convert in to the different fromat

# %%
#Encode the values in categorical data in to the numerical 
from sklearn.preprocessing import LabelEncoder
lc=LabelEncoder()
df_1["Dept_city"]=lc.fit_transform(df_1['Dept_city'])
df_1["Dept_month"]=lc.fit_transform(df_1['Dept_month'])
df_1["arrival_city"]=lc.fit_transform(df_1['arrival_city'])
df_1["day_name"]=lc.fit_transform(df_1['day_name'])

# %%
df_1["Dept_flights_time"]=lc.fit_transform(df_1['Dept_flights_time'])
df_1["arrival_flights_time"]=lc.fit_transform(df_1['arrival_flights_time'])
df_1["Airline_1"]=lc.fit_transform(df_1['Airline_1'])
df_1["Airline_2"]=lc.fit_transform(df_1['Airline_2'])

# %%
df_1["Cabin"]=lc.fit_transform(df_1['Cabin'])

# %%
fig,ax=plt.subplots(1,2,figsize=(15,6))
_gh=df_1['Day_of_Dep'].value_counts().sort_index(ascending=True)
_gh.plot(kind='line',ax=ax[0])
_gh_1=df_1['Day_of_Arr'].value_counts().sort_index(ascending=True)
_gh_1.plot(kind="line",ax=ax[1])
# Out:
# <AxesSubplot:>

# %%
fig,ax=plt.subplots(1,2,figsize=(15,6))
_lf=df_1['Month_of_Dep'].value_counts().sort_index(ascending=True)
_lf.plot(kind='line',ax=ax[0])
_lf_1=df_1['month_of_Arr'].value_counts().sort_index(ascending=True)
_lf_1.plot(kind="line",ax=ax[1])
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df_1.corr(),annot=True,cmap="viridis",square=True)
plt.show()

# %% [markdown]
# Some features in the correlation heatmap are highly correlated let's do some preprocessing

# %%
df_1.head()
# Out:
#    Price  Optimal_hr  Cabin  Dept_city  Dept_month  arrival_city  stops  \
# 0   6159           5      2         19           0            17      0
# 1   6159          11      2         19           0            17      0
# 2   6159          12      2         19           0            17      0
# 3   6159           8      2         19           0            17      0
# 4   6159          13      2         19           0            17      0
#
#    duration  weekday  day_name  dept_hours  arrival_hours  Dept_flights_time  \
# 0     130.0        1         5           9             11                  2
# 1     130.0        1         5          15             17                  0
# 2     130.0        1         5          16             19                  1
# 3     135.0        1         5          12             15                  0
# 4     140.0        1         5          17             20                  1
#
#    arrival_flights_time  Airline_1  Airline_2  Day_of_Dep  Month_of_Dep  \
# 0                     0          6          6          20             4
# 1                     1          6          6          20             4
# 2                     1          6          6          20             4
# 3                     0          6          6          20             4
# 4                     1          6          6          20             4
#
#    Day_of_Arr  month_of_Arr
# 0          20             4
# 1          20             4
# 2          20             4
# 3          20             4
# 4          20             4

# %%
#Drop those highly correlated features 
df_1.drop(labels=["Day_of_Dep","Month_of_Dep","dept_hours"],axis=1,inplace=True)

# %%
#Split the data in to the x and y
x=df_1.drop("Price",1)
y=df_1['Price']

# %%
#Feature selection by xgboost
import xgboost
from xgboost import plot_importance
xgb=xgboost.XGBRegressor()
xgb.fit(x,y)


features=xgb.feature_importances_
columns=x.columns
for i,j in enumerate(features):
    print(columns[i],'--->',j)
    
plt.figure(figsize=(13,6))
plt.title('Feature importance by xgboost')
plt.bar([x for x in range(len(features))],features)
plt.show()
# Out:
# Optimal_hr ---> 0.0043658833
# Cabin ---> 0.57226443
# Dept_city ---> 0.007614324
# Dept_month ---> 0.005554131
# arrival_city ---> 0.004566966
# stops ---> 0.2003647
# duration ---> 0.015988244
# weekday ---> 0.0007800307
# day_name ---> 0.00070636335
# arrival_hours ---> 0.0064773713
# Dept_flights_time ---> 0.0064761983
# arrival_flights_time ---> 0.008720852
# Airline_1 ---> 0.12104379
# Airline_2 ---> 0.03731546
# Day_of_Arr ---> 0.0066837305
# month_of_Arr ---> 0.001077481

# %%
# Out:
# R square:  96.86370790822816

# %% [markdown]
# Transformation of Features
# Why Transformation of Features Are Required?
#
# Linear Regression---Gradient Descent ----Global Minima Algorithms like KNN,K Means,Hierarichal Clustering--- Eucledian Distance Every Point has some vectors and Directiom
#
# Types Of Transformation
#
# Normalization And Standardization
# Scaling to Minimum And Maximum values
# Scaling To Median And Quantiles
# Guassian Transformation Logarithmic Transformation Reciprocal Trnasformation Square Root Transformation Exponential Trnasformation Box Cox Transformation Standardization We try to bring all the variables or features to a similar scale. standarisation means centering the variable at zero. z=(x-x_mean)/std

# %%
#Feature transformation on the Price column since it has so many outliers we need to handle that
df_2=df_1.copy()
import scipy.stats as stat
import pylab
def plot_data(data,feature):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    data[feature].hist()
    plt.subplot(1,2,2)
    stat.probplot(data[feature],dist='norm',plot=pylab)
    plt.show()
plot_data(df_2,"Price")

# %%
df_2["Price"],para=stats.boxcox(df_2["Price"])
plot_data(df_2,"Price")

# %% [markdown]
# Box plot handles the outliers in the "Price" column effiecently so we can proceed that these transformation

# %%
import pandas as pd
import json
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait 
from selenium.webdriver.support import expected_conditions
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np
from datetime import date, timedelta, datetime
import time
df=pd.read_csv("cities.csv")

# %%
df
# Out:
#    Code IMP_codes
# 0   AGR       DEL
# 1   DIB       BOM
# 2   HYD       BLR
# 3   BHJ       HYD
# 4   HBX       MAA
# ..  ...       ...
# 79  IXS       NaN
# 80  CNN       NaN
# 81  GOI       NaN
# 82  AMD       NaN
# 83  TIR       NaN
#
# [84 rows x 2 columns]

# %%
df["IMP_codes"].iloc[29]
# Out:
# 'TRZ'

# %%
from tqdm import tqdm
price=[]
cities=[]
departure_time=[]
arrival_time=[]
via=[]
airline=[]
cabin=[]
scraping_time = []
driver = webdriver.Chrome("C:\Program Files (x86)\chromedriver.exe")

for z in range(30,31):
    driver.refresh()
    for m in range(22, 23):
        driver.refresh()
        for n in range(30):
            driver.refresh()
            if df["IMP_codes"].iloc[m]!=df["IMP_codes"].iloc[n]:
                print("source=",m, "destination=",n, "Dates=",z)
                print(df["IMP_codes"].iloc[m],df["IMP_codes"].iloc[n])
                k=''
                if(z<10):
                    k='0'
                url="https://www.makemytrip.com/flight/search?itinerary="+df["IMP_codes"].iloc[m]+"-"+df["IMP_codes"].iloc[n]+"-"+k+str(z)+"/05/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&cabinClass=B&ccde=IN&lang=eng"
                #driver = webdriver.Chrome("C:/chromedriver.exe")
                driver.get(url)
                soup=BeautifulSoup(driver.page_source, 'lxml')

                price_info=soup.find_all('p',attrs={'class': 'blackText fontSize18 blackFont'})
                flights_info=soup.find_all('p',attrs={'class': 'flightDetailsHead'})
                time_info=soup.find_all('p',attrs={'class':"blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"})
                layover_info=soup.find_all('p',attrs={'class': 'flightsLayoverInfo'})
                airline_info=soup.find_all('span',attrs={'class': 'boldFont blackText airlineName'})
                now1 = datetime.now()
                print("now =", now1)

#price_info
                for i,j in enumerate(price_info):
                    if i<30:
                       a=str(j)
                       price.append(a[43:len(a)-4])
                      
    #flights_info
                for i,j in enumerate(flights_info):
                    if i<60:
                        k=str(j)
                        if len(k)>45:
                            cities.append(k[29:(len(k)-4)])
                            scraping_time.append(now1)

    #time_info
                for i,j in enumerate(time_info):
                    if i<60:
                        k=str(j)
                        if (i%2==0):
                            departure_time.append(k[82:87])
                        if (i%2!=0):
                            arrival_time.append(k[82:87])

    #layover_info
                for i,j in enumerate(layover_info):
                    if i<30:
                        k=str(j)
                        via.append(k[30:len(k)-4])

    #airline_info
                for i,j in enumerate(airline_info):
                    if i<30:            
                        k=str(j)
                        airline.append(k[45:len(k)-7])
                print("**"*50)
                print(len(departure_time), len(price),len(cities),len(arrival_time),len(via),len(airline),len(scraping_time))
# Out:
# source= 22 destination= 0 Dates= 30
# VTZ DEL
# now = 2021-05-10 06:42:14.480279
# ****************************************************************************************************
# 3 3 3 3 3 3 3
# source= 22 destination= 1 Dates= 30
# VTZ BOM
# now = 2021-05-10 06:42:59.717862
# ****************************************************************************************************
# 9 9 9 9 9 9 9
# source= 22 destination= 2 Dates= 30
# VTZ BLR
# now = 2021-05-10 06:43:17.738470
# ****************************************************************************************************
# 12 12 12 12 12 12 12
# source= 22 destination= 3 Dates= 30
# VTZ HYD
# now = 2021-05-10 06:43:40.333647
# ****************************************************************************************************
# 18 18 18 18 18 18 18
# source= 22 destination= 4 Dates= 30
# VTZ MAA
# now = 2021-05-10 06:44:02.991693
# ****************************************************************************************************
# 22 22 22 22 22 22 22
# source= 22 destination= 5 Dates= 30
# VTZ CCU
# now = 2021-05-10 06:44:25.790237
# ****************************************************************************************************
# 28 28 28 28 28 28 28
# source= 22 destination= 6 Dates= 30
# VTZ COK
# now = 2021-05-10 06:44:47.012267
# ****************************************************************************************************
# 31 31 31 31 31 31 31
# source= 22 destination= 7 Dates= 30
# VTZ GOI
# now = 2021-05-10 06:45:09.782856
# ****************************************************************************************************
# 31 31 31 31 31 31 31
# source= 22 destination= 8 Dates= 30
# VTZ PNQ
# now = 2021-05-10 06:45:29.098186
# ****************************************************************************************************
# 34 34 34 34 34 34 34
# source= 22 destination= 9 Dates= 30
# VTZ GAU
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# <ipython-input-126-b0dd77e4245b> in <module>
#      24                 url="https://www.makemytrip.com/flight/search?itinerary="+df["IMP_codes"].iloc[m]+"-"+df["IMP_codes"].iloc[n]+"-"+k+str(z)+"/05/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&cabinClass=B&ccde=IN&lang=eng"
#      25                 #driver = webdriver.Chrome("C:/chromedriver.exe")
# ---> 26                 driver.get(url)
#      27                 soup=BeautifulSoup(driver.page_source, 'lxml')
#      28
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# TimeoutException: Message: timeout: Timed out receiving message from renderer: 300.000
#   (Session info: chrome=90.0.4430.93)

# %%
data = pd.DataFrame(
    {'Price':price,
     'Cities':cities,
     'departure_time':departure_time,
     'arrival_time':arrival_time, 
     'layeover':via,
     'Airline':airline,
     'Scraping_Time':scraping_time
    })

# %%
data
# Out:
#        Price                         Cities departure_time arrival_time  \
# 0     27,088      Srinagar to Pune , 30 May          12:25        18:10
# 1     27,088      Srinagar to Pune , 30 May          09:25        18:10
# 2     40,891  Srinagar to Guwahati , 30 May          14:15        11:05
# 3     42,317  Srinagar to Guwahati , 30 May          09:25        11:05
# 4     42,367  Srinagar to Guwahati , 30 May          12:25        11:05
# ..       ...                            ...            ...          ...
# 98    24,360    Srinagar to Raipur , 30 May          12:50        18:10
# 99    49,074    Srinagar to Raipur , 30 May          14:15        11:50
# 100   49,074    Srinagar to Raipur , 30 May          12:25        11:50
# 101   49,074    Srinagar to Raipur , 30 May          09:25        11:50
# 102   49,632    Srinagar to Raipur , 30 May          12:50        11:50
#
#                                layeover             Airline  \
# 0                  1 stop via New Delhi           Air India
# 1                  1 stop via New Delhi           Air India
# 2    3 stop via Jammu,New Delhi,Kolkata           Air India
# 3          2 stop via New Delhi,Kolkata           Air India
# 4          2 stop via New Delhi,Kolkata           Air India
# ..                                  ...                 ...
# 98                 1 stop via New Delhi  Vistara, Air India
# 99    3 stop via Jammu,New Delhi,Mumbai           Air India
# 100         2 stop via New Delhi,Mumbai           Air India
# 101         2 stop via New Delhi,Mumbai           Air India
# 102         2 stop via New Delhi,Mumbai  Vistara, Air India
#
#                  Scraping_Time
# 0   2021-05-10 06:33:03.064089
# 1   2021-05-10 06:33:03.064089
# 2   2021-05-10 06:33:25.878923
# 3   2021-05-10 06:33:25.878923
# 4   2021-05-10 06:33:25.878923
# ..                         ...
# 98  2021-05-10 06:39:14.102228
# 99  2021-05-10 06:39:14.102228
# 100 2021-05-10 06:39:14.102228
# 101 2021-05-10 06:39:14.102228
# 102 2021-05-10 06:39:14.102228
#
# [103 rows x 7 columns]

# %%
print(len(departure_time), len(price),len(cities),len(arrival_time),len(via),len(airline))
# Out:
# 103 103 103 103 103 103

# %%
data.to_csv("new_business_may27-30-part2.csv", index = False)

# %%
df = pd.read_csv("new_business_may27-30-part2.csv")
df.shape
# Out:
# (103, 7)

# %%
df.tail()
# Out:
#        Price                       Cities departure_time arrival_time  \
# 98    24,360  Srinagar to Raipur , 30 May          12:50        18:10
# 99    49,074  Srinagar to Raipur , 30 May          14:15        11:50
# 100   49,074  Srinagar to Raipur , 30 May          12:25        11:50
# 101   49,074  Srinagar to Raipur , 30 May          09:25        11:50
# 102   49,632  Srinagar to Raipur , 30 May          12:50        11:50
#
#                               layeover             Airline  \
# 98                1 stop via New Delhi  Vistara, Air India
# 99   3 stop via Jammu,New Delhi,Mumbai           Air India
# 100        2 stop via New Delhi,Mumbai           Air India
# 101        2 stop via New Delhi,Mumbai           Air India
# 102        2 stop via New Delhi,Mumbai  Vistara, Air India
#
#                   Scraping_Time
# 98   2021-05-10 06:39:14.102228
# 99   2021-05-10 06:39:14.102228
# 100  2021-05-10 06:39:14.102228
# 101  2021-05-10 06:39:14.102228
# 102  2021-05-10 06:39:14.102228

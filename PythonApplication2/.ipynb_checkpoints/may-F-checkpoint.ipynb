# %%
import pandas as pd
import json
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait 
from selenium.webdriver.support import expected_conditions
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np
from datetime import date, timedelta, datetime
import time
df=pd.read_csv("cities.csv")

# %%
df
# Out:
#    Code IMP_codes
# 0   AGR       DEL
# 1   DIB       BOM
# 2   HYD       BLR
# 3   BHJ       HYD
# 4   HBX       MAA
# ..  ...       ...
# 79  IXS       NaN
# 80  CNN       NaN
# 81  GOI       NaN
# 82  AMD       NaN
# 83  TIR       NaN
#
# [84 rows x 2 columns]

# %%
df["IMP_codes"].iloc[29]
# Out:
# 'TRZ'

# %%
from tqdm import tqdm
price=[]
cities=[]
departure_time=[]
arrival_time=[]
via=[]
airline=[]
cabin=[]
driver = webdriver.Chrome("C:\Program Files (x86)\chromedriver.exe")

for z in range(5,17):
    for m in range(15,20):
        for n in range(30):
            if df["IMP_codes"].iloc[m]!=df["IMP_codes"].iloc[n]:
                print("source=",m, "destination=",n, "Dates=",z)
                print(df["IMP_codes"].iloc[m],df["IMP_codes"].iloc[n])
                k=''
                if(z<10):
                    k='0'
                url="https://www.makemytrip.com/flight/search?itinerary="+df["IMP_codes"].iloc[m]+"-"+df["IMP_codes"].iloc[n]+"-"+k+str(z)+"/05/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&cabinClass=F&ccde=IN&lang=eng"
                #driver = webdriver.Chrome("C:/chromedriver.exe")
                driver.get(url)
                soup=BeautifulSoup(driver.page_source, 'lxml')

                price_info=soup.find_all('p',attrs={'class': 'blackText fontSize18 blackFont'})
                flights_info=soup.find_all('p',attrs={'class': 'flightDetailsHead'})
                time_info=soup.find_all('p',attrs={'class':"blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"})
                layover_info=soup.find_all('p',attrs={'class': 'flightsLayoverInfo'})
                airline_info=soup.find_all('span',attrs={'class': 'boldFont blackText airlineName'})

#price_info
                for i,j in enumerate(price_info):
                    if i<30:
                       a=str(j)
                       price.append(a[43:len(a)-4])
                      
    #flights_info
                for i,j in enumerate(flights_info):
                    if i<60:
                        k=str(j)
                        if len(k)>45:
                            cities.append(k[29:(len(k)-4)])

    #time_info
                for i,j in enumerate(time_info):
                    if i<60:
                        k=str(j)
                        if (i%2==0):
                            departure_time.append(k[82:87])
                        if (i%2!=0):
                            arrival_time.append(k[82:87])

    #layover_info
                for i,j in enumerate(layover_info):
                    if i<30:
                        k=str(j)
                        via.append(k[30:len(k)-4])

    #airline_info
                for i,j in enumerate(airline_info):
                    if i<30:            
                        k=str(j)
                        airline.append(k[45:len(k)-7])
                print("**"*50)
                print(len(departure_time), len(price),len(cities),len(arrival_time),len(via),len(airline))
# Out:
# source= 15 destination= 0 Dates= 5
# CCJ DEL
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 1 Dates= 5
# CCJ BOM
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 2 Dates= 5
# CCJ BLR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 3 Dates= 5
# CCJ HYD
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 4 Dates= 5
# CCJ MAA
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 5 Dates= 5
# CCJ CCU
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 6 Dates= 5
# CCJ COK
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 7 Dates= 5
# CCJ GOI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 8 Dates= 5
# CCJ PNQ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 9 Dates= 5
# CCJ GAU
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 10 Dates= 5
# CCJ LKO
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 11 Dates= 5
# CCJ JAI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 12 Dates= 5
# CCJ PAT
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 13 Dates= 5
# CCJ TRV
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 14 Dates= 5
# CCJ BBI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 16 Dates= 5
# CCJ IXB
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 17 Dates= 5
# CCJ NAG
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 18 Dates= 5
# CCJ VNS
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 19 Dates= 5
# CCJ IDR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 20 Dates= 5
# CCJ CJB
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 21 Dates= 5
# CCJ SXR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 22 Dates= 5
# CCJ VTZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 23 Dates= 5
# CCJ IXR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 24 Dates= 5
# CCJ ATQ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 25 Dates= 5
# CCJ IXC
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 26 Dates= 5
# CCJ RPR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 27 Dates= 5
# CCJ IXE
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 28 Dates= 5
# CCJ IXZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 29 Dates= 5
# CCJ TRZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 0 Dates= 5
# IXB DEL
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 1 Dates= 5
# IXB BOM
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 2 Dates= 5
# IXB BLR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 3 Dates= 5
# IXB HYD
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 4 Dates= 5
# IXB MAA
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 5 Dates= 5
# IXB CCU
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 6 Dates= 5
# IXB COK
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 7 Dates= 5
# IXB GOI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 8 Dates= 5
# IXB PNQ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 9 Dates= 5
# IXB GAU
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 10 Dates= 5
# IXB LKO
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 11 Dates= 5
# IXB JAI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 12 Dates= 5
# IXB PAT
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 13 Dates= 5
# IXB TRV
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 14 Dates= 5
# IXB BBI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 15 Dates= 5
# IXB CCJ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 17 Dates= 5
# IXB NAG
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 18 Dates= 5
# IXB VNS
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 19 Dates= 5
# IXB IDR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 20 Dates= 5
# IXB CJB
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 21 Dates= 5
# IXB SXR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 22 Dates= 5
# IXB VTZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 23 Dates= 5
# IXB IXR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 24 Dates= 5
# IXB ATQ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 25 Dates= 5
# IXB IXC
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 26 Dates= 5
# IXB RPR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 27 Dates= 5
# IXB IXE
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 28 Dates= 5
# IXB IXZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 29 Dates= 5
# IXB TRZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 0 Dates= 5
# NAG DEL
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 1 Dates= 5
# NAG BOM
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 2 Dates= 5
# NAG BLR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 3 Dates= 5
# NAG HYD
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 4 Dates= 5
# NAG MAA
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 5 Dates= 5
# NAG CCU
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 6 Dates= 5
# NAG COK
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 7 Dates= 5
# NAG GOI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 8 Dates= 5
# NAG PNQ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 9 Dates= 5
# NAG GAU
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 10 Dates= 5
# NAG LKO
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 11 Dates= 5
# NAG JAI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 12 Dates= 5
# NAG PAT
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 13 Dates= 5
# NAG TRV
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 14 Dates= 5
# NAG BBI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 15 Dates= 5
# NAG CCJ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 16 Dates= 5
# NAG IXB
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 18 Dates= 5
# NAG VNS
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 19 Dates= 5
# NAG IDR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 20 Dates= 5
# NAG CJB
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 21 Dates= 5
# NAG SXR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 22 Dates= 5
# NAG VTZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 23 Dates= 5
# NAG IXR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 24 Dates= 5
# NAG ATQ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 25 Dates= 5
# NAG IXC
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 26 Dates= 5
# NAG RPR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 27 Dates= 5
# NAG IXE
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 28 Dates= 5
# NAG IXZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 29 Dates= 5
# NAG TRZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 0 Dates= 5
# VNS DEL
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 1 Dates= 5
# VNS BOM
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 2 Dates= 5
# VNS BLR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 3 Dates= 5
# VNS HYD
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 4 Dates= 5
# VNS MAA
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 5 Dates= 5
# VNS CCU
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 6 Dates= 5
# VNS COK
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 7 Dates= 5
# VNS GOI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 8 Dates= 5
# VNS PNQ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 9 Dates= 5
# VNS GAU
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 10 Dates= 5
# VNS LKO
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 11 Dates= 5
# VNS JAI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 12 Dates= 5
# VNS PAT
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 13 Dates= 5
# VNS TRV
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 14 Dates= 5
# VNS BBI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 15 Dates= 5
# VNS CCJ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 16 Dates= 5
# VNS IXB
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 17 Dates= 5
# VNS NAG
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 19 Dates= 5
# VNS IDR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 20 Dates= 5
# VNS CJB
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 21 Dates= 5
# VNS SXR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 22 Dates= 5
# VNS VTZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 23 Dates= 5
# VNS IXR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 24 Dates= 5
# VNS ATQ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 25 Dates= 5
# VNS IXC
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 26 Dates= 5
# VNS RPR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 27 Dates= 5
# VNS IXE
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 28 Dates= 5
# VNS IXZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 29 Dates= 5
# VNS TRZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 0 Dates= 5
# IDR DEL
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 1 Dates= 5
# IDR BOM
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 2 Dates= 5
# IDR BLR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 3 Dates= 5
# IDR HYD
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 4 Dates= 5
# IDR MAA
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 5 Dates= 5
# IDR CCU
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 6 Dates= 5
# IDR COK
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 7 Dates= 5
# IDR GOI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 8 Dates= 5
# IDR PNQ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 9 Dates= 5
# IDR GAU
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 10 Dates= 5
# IDR LKO
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 11 Dates= 5
# IDR JAI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 12 Dates= 5
# IDR PAT
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 13 Dates= 5
# IDR TRV
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 14 Dates= 5
# IDR BBI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 15 Dates= 5
# IDR CCJ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 16 Dates= 5
# IDR IXB
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 17 Dates= 5
# IDR NAG
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 18 Dates= 5
# IDR VNS
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 20 Dates= 5
# IDR CJB
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 21 Dates= 5
# IDR SXR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 22 Dates= 5
# IDR VTZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 23 Dates= 5
# IDR IXR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 24 Dates= 5
# IDR ATQ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 25 Dates= 5
# IDR IXC
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 26 Dates= 5
# IDR RPR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 27 Dates= 5
# IDR IXE
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 28 Dates= 5
# IDR IXZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 29 Dates= 5
# IDR TRZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 0 Dates= 6
# CCJ DEL
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 1 Dates= 6
# CCJ BOM
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 2 Dates= 6
# CCJ BLR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 3 Dates= 6
# CCJ HYD
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 4 Dates= 6
# CCJ MAA
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 5 Dates= 6
# CCJ CCU
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 6 Dates= 6
# CCJ COK
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 7 Dates= 6
# CCJ GOI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 8 Dates= 6
# CCJ PNQ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 9 Dates= 6
# CCJ GAU
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 10 Dates= 6
# CCJ LKO
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 11 Dates= 6
# CCJ JAI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 12 Dates= 6
# CCJ PAT
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 13 Dates= 6
# CCJ TRV
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 14 Dates= 6
# CCJ BBI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 16 Dates= 6
# CCJ IXB
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 17 Dates= 6
# CCJ NAG
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 18 Dates= 6
# CCJ VNS
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 19 Dates= 6
# CCJ IDR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 20 Dates= 6
# CCJ CJB
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 21 Dates= 6
# CCJ SXR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 22 Dates= 6
# CCJ VTZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 23 Dates= 6
# CCJ IXR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 24 Dates= 6
# CCJ ATQ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 25 Dates= 6
# CCJ IXC
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 26 Dates= 6
# CCJ RPR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 27 Dates= 6
# CCJ IXE
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 28 Dates= 6
# CCJ IXZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 29 Dates= 6
# CCJ TRZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 0 Dates= 6
# IXB DEL
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 1 Dates= 6
# IXB BOM
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 2 Dates= 6
# IXB BLR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 3 Dates= 6
# IXB HYD
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 4 Dates= 6
# IXB MAA
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 5 Dates= 6
# IXB CCU
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 6 Dates= 6
# IXB COK
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 7 Dates= 6
# IXB GOI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 8 Dates= 6
# IXB PNQ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 9 Dates= 6
# IXB GAU
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 10 Dates= 6
# IXB LKO
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 11 Dates= 6
# IXB JAI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 12 Dates= 6
# IXB PAT
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 13 Dates= 6
# IXB TRV
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 14 Dates= 6
# IXB BBI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 15 Dates= 6
# IXB CCJ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 17 Dates= 6
# IXB NAG
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 18 Dates= 6
# IXB VNS
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 19 Dates= 6
# IXB IDR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 20 Dates= 6
# IXB CJB
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 21 Dates= 6
# IXB SXR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 22 Dates= 6
# IXB VTZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 23 Dates= 6
# IXB IXR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 24 Dates= 6
# IXB ATQ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 25 Dates= 6
# IXB IXC
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 26 Dates= 6
# IXB RPR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 27 Dates= 6
# IXB IXE
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 28 Dates= 6
# IXB IXZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 29 Dates= 6
# IXB TRZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 0 Dates= 6
# NAG DEL
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 1 Dates= 6
# NAG BOM
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 2 Dates= 6
# NAG BLR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 3 Dates= 6
# NAG HYD
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 4 Dates= 6
# NAG MAA
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 5 Dates= 6
# NAG CCU
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 6 Dates= 6
# NAG COK
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 7 Dates= 6
# NAG GOI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 8 Dates= 6
# NAG PNQ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 9 Dates= 6
# NAG GAU
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 10 Dates= 6
# NAG LKO
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 11 Dates= 6
# NAG JAI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 12 Dates= 6
# NAG PAT
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 13 Dates= 6
# NAG TRV
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 14 Dates= 6
# NAG BBI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 15 Dates= 6
# NAG CCJ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 16 Dates= 6
# NAG IXB
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 18 Dates= 6
# NAG VNS
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 19 Dates= 6
# NAG IDR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 20 Dates= 6
# NAG CJB
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 21 Dates= 6
# NAG SXR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 22 Dates= 6
# NAG VTZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 23 Dates= 6
# NAG IXR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 24 Dates= 6
# NAG ATQ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 25 Dates= 6
# NAG IXC
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 26 Dates= 6
# NAG RPR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 27 Dates= 6
# NAG IXE
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 28 Dates= 6
# NAG IXZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 29 Dates= 6
# NAG TRZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 0 Dates= 6
# VNS DEL
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 1 Dates= 6
# VNS BOM
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 2 Dates= 6
# VNS BLR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 3 Dates= 6
# VNS HYD
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 4 Dates= 6
# VNS MAA
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 5 Dates= 6
# VNS CCU
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 6 Dates= 6
# VNS COK
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 7 Dates= 6
# VNS GOI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 8 Dates= 6
# VNS PNQ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 9 Dates= 6
# VNS GAU
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 10 Dates= 6
# VNS LKO
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 11 Dates= 6
# VNS JAI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 12 Dates= 6
# VNS PAT
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 13 Dates= 6
# VNS TRV
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 14 Dates= 6
# VNS BBI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 15 Dates= 6
# VNS CCJ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 16 Dates= 6
# VNS IXB
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 17 Dates= 6
# VNS NAG
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 19 Dates= 6
# VNS IDR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 20 Dates= 6
# VNS CJB
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 21 Dates= 6
# VNS SXR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 22 Dates= 6
# VNS VTZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 23 Dates= 6
# VNS IXR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 24 Dates= 6
# VNS ATQ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 25 Dates= 6
# VNS IXC
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 26 Dates= 6
# VNS RPR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 27 Dates= 6
# VNS IXE
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 28 Dates= 6
# VNS IXZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 29 Dates= 6
# VNS TRZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 0 Dates= 6
# IDR DEL
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 1 Dates= 6
# IDR BOM
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 2 Dates= 6
# IDR BLR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 3 Dates= 6
# IDR HYD
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 4 Dates= 6
# IDR MAA
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 5 Dates= 6
# IDR CCU
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 6 Dates= 6
# IDR COK
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 7 Dates= 6
# IDR GOI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 8 Dates= 6
# IDR PNQ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 9 Dates= 6
# IDR GAU
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 10 Dates= 6
# IDR LKO
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 11 Dates= 6
# IDR JAI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 12 Dates= 6
# IDR PAT
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 13 Dates= 6
# IDR TRV
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 14 Dates= 6
# IDR BBI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 15 Dates= 6
# IDR CCJ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 16 Dates= 6
# IDR IXB
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 17 Dates= 6
# IDR NAG
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 18 Dates= 6
# IDR VNS
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 20 Dates= 6
# IDR CJB
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 21 Dates= 6
# IDR SXR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 22 Dates= 6
# IDR VTZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 23 Dates= 6
# IDR IXR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 24 Dates= 6
# IDR ATQ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 25 Dates= 6
# IDR IXC
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 26 Dates= 6
# IDR RPR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 27 Dates= 6
# IDR IXE
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 28 Dates= 6
# IDR IXZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 29 Dates= 6
# IDR TRZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 0 Dates= 7
# CCJ DEL
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 1 Dates= 7
# CCJ BOM
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 2 Dates= 7
# CCJ BLR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 3 Dates= 7
# CCJ HYD
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 4 Dates= 7
# CCJ MAA
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 5 Dates= 7
# CCJ CCU
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 6 Dates= 7
# CCJ COK
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 7 Dates= 7
# CCJ GOI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 8 Dates= 7
# CCJ PNQ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 9 Dates= 7
# CCJ GAU
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 10 Dates= 7
# CCJ LKO
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 11 Dates= 7
# CCJ JAI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 12 Dates= 7
# CCJ PAT
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 13 Dates= 7
# CCJ TRV
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 14 Dates= 7
# CCJ BBI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 16 Dates= 7
# CCJ IXB
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 15 destination= 17 Dates= 7
# CCJ NAG
# ...
# 0 0 0 0 0 0
# source= 16 destination= 15 Dates= 16
# IXB CCJ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 17 Dates= 16
# IXB NAG
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 18 Dates= 16
# IXB VNS
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 19 Dates= 16
# IXB IDR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 20 Dates= 16
# IXB CJB
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 21 Dates= 16
# IXB SXR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 22 Dates= 16
# IXB VTZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 23 Dates= 16
# IXB IXR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 24 Dates= 16
# IXB ATQ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 25 Dates= 16
# IXB IXC
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 26 Dates= 16
# IXB RPR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 27 Dates= 16
# IXB IXE
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 28 Dates= 16
# IXB IXZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 16 destination= 29 Dates= 16
# IXB TRZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 0 Dates= 16
# NAG DEL
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 1 Dates= 16
# NAG BOM
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 2 Dates= 16
# NAG BLR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 3 Dates= 16
# NAG HYD
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 4 Dates= 16
# NAG MAA
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 5 Dates= 16
# NAG CCU
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 6 Dates= 16
# NAG COK
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 7 Dates= 16
# NAG GOI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 8 Dates= 16
# NAG PNQ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 9 Dates= 16
# NAG GAU
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 10 Dates= 16
# NAG LKO
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 11 Dates= 16
# NAG JAI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 12 Dates= 16
# NAG PAT
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 13 Dates= 16
# NAG TRV
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 14 Dates= 16
# NAG BBI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 15 Dates= 16
# NAG CCJ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 16 Dates= 16
# NAG IXB
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 18 Dates= 16
# NAG VNS
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 19 Dates= 16
# NAG IDR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 20 Dates= 16
# NAG CJB
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 21 Dates= 16
# NAG SXR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 22 Dates= 16
# NAG VTZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 23 Dates= 16
# NAG IXR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 24 Dates= 16
# NAG ATQ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 25 Dates= 16
# NAG IXC
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 26 Dates= 16
# NAG RPR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 27 Dates= 16
# NAG IXE
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 28 Dates= 16
# NAG IXZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 17 destination= 29 Dates= 16
# NAG TRZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 0 Dates= 16
# VNS DEL
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 1 Dates= 16
# VNS BOM
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 2 Dates= 16
# VNS BLR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 3 Dates= 16
# VNS HYD
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 4 Dates= 16
# VNS MAA
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 5 Dates= 16
# VNS CCU
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 6 Dates= 16
# VNS COK
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 7 Dates= 16
# VNS GOI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 8 Dates= 16
# VNS PNQ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 9 Dates= 16
# VNS GAU
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 10 Dates= 16
# VNS LKO
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 11 Dates= 16
# VNS JAI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 12 Dates= 16
# VNS PAT
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 13 Dates= 16
# VNS TRV
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 14 Dates= 16
# VNS BBI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 15 Dates= 16
# VNS CCJ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 16 Dates= 16
# VNS IXB
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 17 Dates= 16
# VNS NAG
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 19 Dates= 16
# VNS IDR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 20 Dates= 16
# VNS CJB
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 21 Dates= 16
# VNS SXR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 22 Dates= 16
# VNS VTZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 23 Dates= 16
# VNS IXR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 24 Dates= 16
# VNS ATQ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 25 Dates= 16
# VNS IXC
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 26 Dates= 16
# VNS RPR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 27 Dates= 16
# VNS IXE
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 28 Dates= 16
# VNS IXZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 18 destination= 29 Dates= 16
# VNS TRZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 0 Dates= 16
# IDR DEL
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 1 Dates= 16
# IDR BOM
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 2 Dates= 16
# IDR BLR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 3 Dates= 16
# IDR HYD
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 4 Dates= 16
# IDR MAA
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 5 Dates= 16
# IDR CCU
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 6 Dates= 16
# IDR COK
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 7 Dates= 16
# IDR GOI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 8 Dates= 16
# IDR PNQ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 9 Dates= 16
# IDR GAU
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 10 Dates= 16
# IDR LKO
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 11 Dates= 16
# IDR JAI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 12 Dates= 16
# IDR PAT
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 13 Dates= 16
# IDR TRV
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 14 Dates= 16
# IDR BBI
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 15 Dates= 16
# IDR CCJ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 16 Dates= 16
# IDR IXB
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 17 Dates= 16
# IDR NAG
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 18 Dates= 16
# IDR VNS
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 20 Dates= 16
# IDR CJB
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 21 Dates= 16
# IDR SXR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 22 Dates= 16
# IDR VTZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 23 Dates= 16
# IDR IXR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 24 Dates= 16
# IDR ATQ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 25 Dates= 16
# IDR IXC
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 26 Dates= 16
# IDR RPR
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 27 Dates= 16
# IDR IXE
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 28 Dates= 16
# IDR IXZ
# ****************************************************************************************************
# 0 0 0 0 0 0
# source= 19 destination= 29 Dates= 16
# IDR TRZ
# ****************************************************************************************************
# 0 0 0 0 0 0

# %%
data = pd.DataFrame(
    {'Price':price,
     'Cities':cities,
     'departure_time':departure_time,
     'arrival_time':arrival_time, 
     'layeover':via,
     'Airline':airline
    })

# %%
data
# Out:
# Empty DataFrame
# Columns: [Price, Cities, departure_time, arrival_time, layeover, Airline]
# Index: []

# %%
print(len(departure_time), len(price),len(cities),len(arrival_time),len(via),len(airline))
# Out:
# 0 0 0 0 0 0

# %%
data.to_csv("5-16_data-f-may.csv")

# %%
data_1=pd.read_csv("0-5.csv")
data_2=pd.read_csv("0-5_data.csv")

# %%
data_1.shape

# %%
data_2.shape

# %%
data_1=data_1.append(data_2)

# %%
data_1=data_1.drop_duplicates(keep="first")

# %%
data_1.shape

# %%
data_1.to_csv("0-5final.csv")

# %%
print(len(price),len(cities),len(departure_time),len(arrival_time),len(via),len(airline))

# %%
cities

# %%
soup.find_all('p')

# %%
for i in codes["Code"]:
    for j in codes["Code"]:
        print(i,j)

# %%
url="https://www.makemytrip.com/flight/search?itinerary=DEL-BOM-15/04/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&cabinClass=E&ccde=IN&lang=eng"
driver = webdriver.Chrome("C:/chromedriver.exe")
driver.get(url)
soup=BeautifulSoup(driver.page_source, 'lxml')

# %%
soup.find_all('ul')#,attrs={"class":"guestCounter"})

# %%
price_info=soup.find_all('p',attrs={'class': 'blackText fontSize18 blackFont'})

# %%
price=[]
for j,i in enumerate(price_info):
    if j<10:
        a=str(i)
        price.append(a[43:len(a)-4])
len(price)

# %%
s='<p class="blackText fontSize18 blackFont">₹'
len(s)

# %%
flights_info=soup.find_all('p',attrs={'class': 'flightDetailsHead'})
cities=[]
k=0
for i,j in enumerate(flights_info):
    if i<=10:
        k=str(j)
        if len(k)>45:
            cities.append(k[29:(len(k)-4)])

# %%
cities

# %%
time_info=soup.find_all('p',attrs={'class':"blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"})
departure_time=[]
arrival_time=[]

for i,j in enumerate(b):
    k=str(j)
    if (i%2==0):
        departure_time.append(k[82:87])
    else:
        arrival_time.append(k[82:87])

# %%
layover_info=soup.find_all('p',attrs={'class': 'flightsLayoverInfo'})

# %%
via=[]
for i in c:
    via1=[]
    k=str(i)
    via1.append(k[30:len(k)-4])
    via.append(via1)

# %%
len(via)

# %%
airline_info=soup.find_all('span',attrs={'class': 'boldFont blackText airlineName'})
airline=[]
for i,j in enumerate(d):
    k=str(j)
    airline.append(k[45:len(k)-7])

len(airline)

# %%
s="<span class='boldFont blackText airlineName'>"
len(s)
